# %% [markdown]
# # Individual in-play candidates

# %%
# !pip install plotly

import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import os

# Set a clean, modern default theme for all our plots
pio.templates.default = "plotly_white"

print("Libraries imported successfully.")
# Out:
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (25.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Libraries imported successfully.

# %% [markdown]
# ## Import the Data (CVs Sent, 1st interview, Placements, Rejected)

# %% [markdown]
# ### CVs Sent

# %%
# CV Sent dataset
cv_sents = pd.read_csv('CVs Sent (Last 90 Days).csv')

# First 5 rows
display(cv_sents.head())
# Out:
#    ﻿"Job ID"     Job Owner Created Date           Owner Group   Company  \
# 0        196  Brad Houston   05/10/2025    Brad Houston  EMEA  Blockaid
# 1        196  Brad Houston   09/10/2025     Max Hogarth  EMEA  Blockaid
# 2        196  Brad Houston   14/10/2025  Harry Thornton  EMEA  Blockaid
# 3        196  Brad Houston   20/10/2025      Joe Marron  EMEA  Blockaid
# 4        196  Brad Houston   22/10/2025     Ben Clifton  EMEA  Blockaid
#
#                                 Job Title Job Priority      Candidate  \
# 0  Enterprise Account Executive (Fintech)          NaN  Hassan Makiya
# 1  Enterprise Account Executive (Fintech)          NaN  DEREK ORGERON
# 2  Enterprise Account Executive (Fintech)          NaN     STONE GODI
# 3  Enterprise Account Executive (Fintech)          NaN  Wesley Wooten
# 4  Enterprise Account Executive (Fintech)          NaN  Carlos Torres
#
#                       Source  Time to Send  CV Sent ID
# 0        LinkedIn Job Advert           410        4609
# 1  LinkedIn Recruiter Inmail           414        4667
# 2                   Referral           419        4718
# 3  LinkedIn Recruiter Inmail           425        4797
# 4   Cold Call via Signalhire           427        4815

# %% [markdown]
# ### 1st interviews

# %%
# Interviews dataset
first_interviews = pd.read_csv('1st Interviews (Last 90 Days).csv')

# First 5 rows
display(first_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date        Owner Group    Company  \
# 0      05/10/2025     06/10/2025   Joe Marron  EMEA        Rox
# 1      05/10/2025     05/10/2025  James Whipp  EMEA   Capsa AI
# 2      05/10/2025     05/10/2025  James Whipp  EMEA   Capsa AI
# 3      05/10/2025     05/10/2025  James Whipp  EMEA  PointFive
# 4      05/10/2025     03/10/2025  Ben Clifton  EMEA   Metaview
#
#                            Job Title Job Priority       Candidate  \
# 0                        ENT AE East          Hot    Clay Tolbert
# 1                      Head of Sales          Hot  Tom Richardson
# 2                      Head of Sales          Hot      Chris Webb
# 3  Channel & Alliances Director - UK          Hot     ABRAR AHMED
# 4   Metaview - UK MM / Enterprise AE          Hot     Josh Buller
#
#   Client Contact    Job Type Interview Type CRM Interview Type  \
# 0       Adam Ali  Contingent  1st Interview      1st Interview
# 1            NaN  Contingent  1st Interview      1st Interview
# 2            NaN  Contingent  1st Interview      1st Interview
# 3            NaN  Contingent  1st Interview      1st Interview
# 4            NaN  Contingent  1st Interview      1st Interview
#
#                    Source          Job Owner  Job ID  Interview ID
# 0                Bullhorn         James Cato     721         17990
# 1        LinkedIn Message        James Whipp     676         17995
# 2        LinkedIn Message        James Whipp     676         17996
# 3                Bullhorn        James Whipp     661         17997
# 4  Email & Text follow up  Jordan Goodenough     681         17998

# %% [markdown]
# ### 2nd interviews

# %%
# 2nd interviews dataset
second_interviews = pd.read_csv('2nd Interviews (Last 90 Days).csv')

# First 5 rows
display(second_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date             Owner Group        Company  \
# 0      05/10/2025     03/10/2025        Joe Marron  EMEA    groundcover
# 1      05/10/2025     13/10/2025       Sam Rudston  EMEA          Dash0
# 2      05/10/2025     05/10/2025  Samson Abodunrin  EMEA     Antithesis
# 3      05/10/2025     05/10/2025  Samson Abodunrin  EMEA     Antithesis
# 4      05/10/2025     05/10/2025  Samson Abodunrin  EMEA  Safe Security
#
#                                            Job Title Job Priority  \
# 0                                 SDR (Anywhere U.S)          Hot
# 1  Enterprise Account Executive - Nordics / Stock...          Hot
# 2                Enterprise Account Executive - West          NaN
# 3                Enterprise Account Executive - West          NaN
# 4                                        RVP Central          Hot
#
#         Candidate    Client Contact    Job Type     Interview Type  \
# 0    Tiez Allison    Ryan  Hamilton  Contingent  Further Interview
# 1    Martin Grahn  Mirko  Novakovic  Contingent  Further Interview
# 2    Jeff Andrews               NaN  Contingent  Further Interview
# 3   Nick Enthoven               NaN  Contingent  Further Interview
# 4  Sean Latterner   Daniel  Cuffley  Contingent  Further Interview
#
#   CRM Interview Type                     Source          Job Owner  Job ID  \
# 0      2nd Interview  LinkedIn Recruiter Inmail         Joe Marron     565
# 1      2nd Interview           LinkedIn Message  Annalisa Girgenti     650
# 2      2nd Interview                   Bullhorn  Annalisa Girgenti     528
# 3      2nd Interview                   Bullhorn  Annalisa Girgenti     528
# 4      2nd Interview     Email & Text follow up   Samson Abodunrin     643
#
#    Interview ID
# 0         17991
# 1         18003
# 2         18006
# 3         18007
# 4         18010

# %% [markdown]
# ### 3rd interviews

# %%
# Interviews dataset
third_interviews = pd.read_csv('3rd Interviews (Last 90 Days).csv')

# First 5 rows
display(third_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date             Owner Group        Company  \
# 0      05/10/2025     07/10/2025        Joe Marron  EMEA       Doxel.ai
# 1      05/10/2025     05/10/2025  Samson Abodunrin  EMEA        Oscilar
# 2      05/10/2025     05/10/2025  Samson Abodunrin  EMEA        Oscilar
# 3      05/10/2025     05/10/2025  Samson Abodunrin  EMEA      Blink Ops
# 4      05/10/2025     05/10/2025  Samson Abodunrin  EMEA  Safe Security
#
#                                           Job Title Job Priority  \
# 0  CS1 Doxel - Regional Sales Director (CST or EST)          Hot
# 1                                 BDR Manager - NYC          Hot
# 2                                  MidMarket Leader          Hot
# 3                 Enterprise Account Executive (UK)          Hot
# 4                                       RVP Central          Hot
#
#           Candidate   Client Contact         Job Type     Interview Type  \
# 0  Garrison Goodman    Daniel Cheney  Committed Spend  Further Interview
# 1       David Gagas   Neha  Narkhede       Contingent  Further Interview
# 2  Lucas Rabinowitz   Neha  Narkhede       Contingent  Further Interview
# 3        Rob Preedy  Aaron Beveridge       Contingent  Further Interview
# 4    Sean Latterner  Daniel  Cuffley       Contingent  Further Interview
#
#   CRM Interview Type                     Source         Job Owner  Job ID  \
# 0      3rd Interview   Cold Call via Signalhire        Joe Marron     567
# 1      3rd Interview                Sales Robot  Samson Abodunrin     596
# 2      3rd Interview                Sales Robot  Samson Abodunrin     666
# 3      3rd Interview  LinkedIn Recruiter Inmail      Brad Houston     604
# 4      3rd Interview     Email & Text follow up  Samson Abodunrin     643
#
#    Interview ID
# 0         17993
# 1         18005
# 2         18008
# 3         18009
# 4         18011

# %% [markdown]
# ### 4th interviews

# %%
# Interviews dataset
fourth_interviews = pd.read_csv('4th Interviews (Last 90 Days).csv')

# First 5 rows
display(fourth_interviews.tail())
# Out:
#     ﻿"Created Date" Interview Date             Owner Group   Company  \
# 138      19/12/2025     19/12/2025  Samson Abodunrin  EMEA   Oscilar
# 139      19/12/2025     22/12/2025      Brad Houston  EMEA  Blockaid
# 140      19/12/2025     19/12/2025       Max Hogarth  EMEA  TraceBit
# 141      22/12/2025     30/12/2025       Max Hogarth  EMEA      Maze
# 142      25/12/2025     22/12/2025        James Cato    US       Rox
#
#                              Job Title Job Priority         Candidate  \
# 138                   Enterprise AE x5          Hot     Daniel Grasso
# 139          Technical Account Manager          Hot  Sean MacWilliams
# 140              Account Executive NYC          Hot     Ryan Drillock
# 141          Technical Success Manager          Hot        Aaron Lake
# 142  Sales Engineer (NY / Austin / SF)          Hot        Ryan Kerbs
#
#     Client Contact    Job Type     Interview Type CRM Interview Type  \
# 138            NaN  Contingent  Further Interview      4th Interview
# 139  Glenn Rachlin  Contingent  Further Interview      4th Interview
# 140            NaN  Contingent  Further Interview      4th Interview
# 141            NaN  Contingent  Further Interview      4th Interview
# 142            NaN  Contingent  Further Interview      4th Interview
#
#                         Source          Job Owner  Job ID  Interview ID
# 138                   Bullhorn   Samson Abodunrin     731         20568
# 139  LinkedIn Recruiter Inmail       Brad Houston     824         20570
# 140  LinkedIn Recruiter Inmail  Annalisa Girgenti     770         20571
# 141  LinkedIn Recruiter Inmail        Max Hogarth     841         20601
# 142  LinkedIn Recruiter Inmail         James Cato     829         20620

# %% [markdown]
# ### Rejected Candidates

# %%
# Rejects dataset
rejects = pd.read_csv('Rejected Candidates (Last 90 Days).csv')

rejects.rename(columns={'﻿"Job ID"' : 'Job ID'}, inplace=True)

rejects = rejects[['Job ID', 'Candidate']]

# First 5 rows
display(rejects.head())
# Out:
#    Job ID       Candidate
# 0     110    Mark Ghannam
# 1     110  Matthias Funke
# 2     110       Dan Croft
# 3     110   Vyas Adhikari
# 4     110       Miguel L.

# %% [markdown]
# ### Offers

# %%
# Offers dataset
offers = pd.read_csv('Offers (Last 90 Days).csv')

offers = offers[['Job ID', 'Candidate']]

# Last 5 rows
display(offers.tail())
# Out:
#     Job ID           Candidate
# 75     702        Ciaran Deasy
# 76     713  Christopher Devlin
# 77     770       Ryan Drillock
# 78     708        Sean Guillen
# 79     829          Ryan Kerbs

# %% [markdown]
# ## Re-structure the data, changing their fields

# %%
# Rename the Kpi Date columns to CV Sent Date, change that to datetime type
cv_sents.rename(columns={'Created Date' : 'CV Sent Date', '﻿"Job ID"' : 'Job ID'}, inplace=True)

# Change the CV Sent Date to datetime type
cv_sents['CV Sent Date'] = pd.to_datetime(cv_sents['CV Sent Date'], format='%d/%m/%Y')
cv_sents = cv_sents[['Job ID', 'Owner', 'Company', 'Job Title', 'CV Sent Date', 'Candidate']]

# Display the new dataset
cv_sents.head()
# Out:
#    Job ID           Owner   Company                               Job Title  \
# 0     196    Brad Houston  Blockaid  Enterprise Account Executive (Fintech)
# 1     196     Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 2     196  Harry Thornton  Blockaid  Enterprise Account Executive (Fintech)
# 3     196      Joe Marron  Blockaid  Enterprise Account Executive (Fintech)
# 4     196     Ben Clifton  Blockaid  Enterprise Account Executive (Fintech)
#
#   CV Sent Date      Candidate
# 0   2025-10-05  Hassan Makiya
# 1   2025-10-09  DEREK ORGERON
# 2   2025-10-14     STONE GODI
# 3   2025-10-20  Wesley Wooten
# 4   2025-10-22  Carlos Torres

# %%
# Rename the Kpi Date columns to Interview Date, change that to datetime type
first_interviews.rename(columns={'Interview Date' : '1st_Interview Date'}, inplace=True)
second_interviews.rename(columns={'Interview Date' : '2nd_Interview Date'}, inplace=True)
third_interviews.rename(columns={'Interview Date' : '3rd_Interview Date'}, inplace=True)
fourth_interviews.rename(columns={'Interview Date' : '4th_Interview Date'}, inplace=True)

# Change the Create Date to datetime type
first_interviews['1st_Interview Date'] = pd.to_datetime(first_interviews['1st_Interview Date'], format='%d/%m/%Y')
first_interviews = first_interviews[['Job ID', '1st_Interview Date', 'Candidate']]

second_interviews['2nd_Interview Date'] = pd.to_datetime(second_interviews['2nd_Interview Date'], format='%d/%m/%Y')
second_interviews = second_interviews[['Job ID', '2nd_Interview Date', 'Candidate']]

third_interviews['3rd_Interview Date'] = pd.to_datetime(third_interviews['3rd_Interview Date'], format='%d/%m/%Y')
third_interviews = third_interviews[['Job ID', '3rd_Interview Date', 'Candidate']]

fourth_interviews['4th_Interview Date'] = pd.to_datetime(fourth_interviews['4th_Interview Date'], format='%d/%m/%Y')
fourth_interviews = fourth_interviews[['Job ID', '4th_Interview Date','Candidate']]

# %% [markdown]
# ## Create a few helper columns to get the status of CVs Sent to Clients

# %%
# Apply helper columns to get the status of CVs
first_interviews['Interview_1st'] = True
second_interviews['Interview_2nd'] = True
third_interviews['Interview_3rd'] = True
fourth_interviews['Interview_4th'] = True
offers['Offer'] = True
rejects['Rejected'] = True

# %%
first_interviews.head()
# Out:
#    Job ID 1st_Interview Date       Candidate  Interview_1st
# 0     721         2025-10-06    Clay Tolbert           True
# 1     676         2025-10-05  Tom Richardson           True
# 2     676         2025-10-05      Chris Webb           True
# 3     661         2025-10-05     ABRAR AHMED           True
# 4     681         2025-10-03     Josh Buller           True

# %% [markdown]
# ### Merge the CV records with the interviews

# %%
# Merge the CV record with the 1st interview record
merged_cv_sent_status = cv_sents.merge(
    first_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 2nd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    second_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 3rd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    third_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 4th interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    fourth_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the offers record
merged_cv_sent_status = merged_cv_sent_status.merge(
    offers,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the rejected record
merged_cv_sent_status = merged_cv_sent_status.merge(
    rejects,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Print the final list
display(merged_cv_sent_status)
# Out:
#       Job ID              Owner          Company  \
# 0        110                NaN              NaN
# 1        110                NaN              NaN
# 2        110                NaN              NaN
# 3        110                NaN              NaN
# 4        110                NaN              NaN
# ...      ...                ...              ...
# 1474     870        Max Hogarth  Native Security
# 1475     871      Georgia Price     LaunchDarkly
# 1476     871  Jordan Goodenough     LaunchDarkly
# 1477     871   Samson Abodunrin     LaunchDarkly
# 1478     873         James Cato       CodeRabbit
#
#                                       Job Title CV Sent Date  \
# 0                                           NaN          NaT
# 1                                           NaN          NaT
# 2                                           NaN          NaT
# 3                                           NaN          NaT
# 4                                           NaN          NaT
# ...                                         ...          ...
# 1474  Enterprise Account Executive (North-East)   2025-12-17
# 1475                           Strategic AE U.S   2025-12-19
# 1476                           Strategic AE U.S   2025-12-18
# 1477                           Strategic AE U.S   2025-12-19
# 1478                        VP Enterprise Sales   2025-12-18
#
#              Candidate 1st_Interview Date Interview_1st 2nd_Interview Date  \
# 0            Ali Sezer                NaT           NaN                NaT
# 1            Dan Croft                NaT           NaN                NaT
# 2         Mark Ghannam                NaT           NaN                NaT
# 3       Matthias Funke                NaT           NaN                NaT
# 4            Miguel L.                NaT           NaN                NaT
# ...                ...                ...           ...                ...
# 1474        Rich Kroll                NaT           NaN                NaT
# 1475       Dan DiPalma                NaT           NaN                NaT
# 1476     Paul Plofchan                NaT           NaN                NaT
# 1477  WILLIAM WOLLISON                NaT           NaN                NaT
# 1478      Andrew Sweet         2025-12-19          True         2025-12-22
#
#      Interview_2nd 3rd_Interview Date Interview_3rd 4th_Interview Date  \
# 0              NaN                NaT           NaN                NaT
# 1              NaN                NaT           NaN                NaT
# 2              NaN                NaT           NaN                NaT
# 3              NaN                NaT           NaN                NaT
# 4              NaN                NaT           NaN                NaT
# ...            ...                ...           ...                ...
# 1474           NaN                NaT           NaN                NaT
# 1475           NaN                NaT           NaN                NaT
# 1476           NaN                NaT           NaN                NaT
# 1477           NaN                NaT           NaN                NaT
# 1478          True                NaT           NaN                NaT
#
#      Interview_4th Offer Rejected
# 0              NaN   NaN     True
# 1              NaN   NaN     True
# 2              NaN   NaN     True
# 3              NaN   NaN     True
# 4              NaN   NaN     True
# ...            ...   ...      ...
# 1474           NaN   NaN      NaN
# 1475           NaN   NaN      NaN
# 1476           NaN   NaN      NaN
# 1477           NaN   NaN      NaN
# 1478           NaN   NaN      NaN
#
# [1479 rows x 16 columns]

# %%
merged_cv_sent_status.head()
# Out:
#    Job ID Owner Company Job Title CV Sent Date       Candidate  \
# 0     110   NaN     NaN       NaN          NaT       Ali Sezer
# 1     110   NaN     NaN       NaN          NaT       Dan Croft
# 2     110   NaN     NaN       NaN          NaT    Mark Ghannam
# 3     110   NaN     NaN       NaN          NaT  Matthias Funke
# 4     110   NaN     NaN       NaN          NaT       Miguel L.
#
#   1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0                NaT           NaN                NaT           NaN
# 1                NaT           NaN                NaT           NaN
# 2                NaT           NaN                NaT           NaN
# 3                NaT           NaN                NaT           NaN
# 4                NaT           NaN                NaT           NaN
#
#   3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                NaT           NaN                NaT           NaN   NaN
# 1                NaT           NaN                NaT           NaN   NaN
# 2                NaT           NaN                NaT           NaN   NaN
# 3                NaT           NaN                NaT           NaN   NaN
# 4                NaT           NaN                NaT           NaN   NaN
#
#   Rejected
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %% [markdown]
# ### Change the status of the candidates

# %%
def determine_status(row):
    # 1. Highest Priority: Is it Rejected?
    if row['Rejected'] == True:
        return 'Rejected'
    
    # 2. Next Priority: Is there an Offer?
    elif row['Offer'] == True:
        return 'Offer'
    
    # 3. Check Interview Stages (Backwards from latest)
    elif row['Interview_4th'] == True:
        return '4th Interview'
    elif row['Interview_3rd'] == True:
        return '3rd Interview'
    elif row['Interview_2nd'] == True:
        return '2nd Interview'
    elif row['Interview_1st'] == True:
        return '1st Interview'
    
    # 4. Default
    else:
        return 'CV Sent'

# Apply it to the DataFrame
merged_cv_sent_status['Status'] = merged_cv_sent_status.apply(determine_status, axis=1)

display(merged_cv_sent_status)
# Out:
#       Job ID              Owner          Company  \
# 0        110                NaN              NaN
# 1        110                NaN              NaN
# 2        110                NaN              NaN
# 3        110                NaN              NaN
# 4        110                NaN              NaN
# ...      ...                ...              ...
# 1474     870        Max Hogarth  Native Security
# 1475     871      Georgia Price     LaunchDarkly
# 1476     871  Jordan Goodenough     LaunchDarkly
# 1477     871   Samson Abodunrin     LaunchDarkly
# 1478     873         James Cato       CodeRabbit
#
#                                       Job Title CV Sent Date  \
# 0                                           NaN          NaT
# 1                                           NaN          NaT
# 2                                           NaN          NaT
# 3                                           NaN          NaT
# 4                                           NaN          NaT
# ...                                         ...          ...
# 1474  Enterprise Account Executive (North-East)   2025-12-17
# 1475                           Strategic AE U.S   2025-12-19
# 1476                           Strategic AE U.S   2025-12-18
# 1477                           Strategic AE U.S   2025-12-19
# 1478                        VP Enterprise Sales   2025-12-18
#
#              Candidate 1st_Interview Date Interview_1st 2nd_Interview Date  \
# 0            Ali Sezer                NaT           NaN                NaT
# 1            Dan Croft                NaT           NaN                NaT
# 2         Mark Ghannam                NaT           NaN                NaT
# 3       Matthias Funke                NaT           NaN                NaT
# 4            Miguel L.                NaT           NaN                NaT
# ...                ...                ...           ...                ...
# 1474        Rich Kroll                NaT           NaN                NaT
# 1475       Dan DiPalma                NaT           NaN                NaT
# 1476     Paul Plofchan                NaT           NaN                NaT
# 1477  WILLIAM WOLLISON                NaT           NaN                NaT
# 1478      Andrew Sweet         2025-12-19          True         2025-12-22
#
#      Interview_2nd 3rd_Interview Date Interview_3rd 4th_Interview Date  \
# 0              NaN                NaT           NaN                NaT
# 1              NaN                NaT           NaN                NaT
# 2              NaN                NaT           NaN                NaT
# 3              NaN                NaT           NaN                NaT
# 4              NaN                NaT           NaN                NaT
# ...            ...                ...           ...                ...
# 1474           NaN                NaT           NaN                NaT
# 1475           NaN                NaT           NaN                NaT
# 1476           NaN                NaT           NaN                NaT
# 1477           NaN                NaT           NaN                NaT
# 1478          True                NaT           NaN                NaT
#
#      Interview_4th Offer Rejected         Status
# 0              NaN   NaN     True       Rejected
# 1              NaN   NaN     True       Rejected
# 2              NaN   NaN     True       Rejected
# 3              NaN   NaN     True       Rejected
# 4              NaN   NaN     True       Rejected
# ...            ...   ...      ...            ...
# 1474           NaN   NaN      NaN        CV Sent
# 1475           NaN   NaN      NaN        CV Sent
# 1476           NaN   NaN      NaN        CV Sent
# 1477           NaN   NaN      NaN        CV Sent
# 1478           NaN   NaN      NaN  2nd Interview
#
# [1479 rows x 17 columns]

# %% [markdown]
# ### Add the column of Action Date - Interview/CV Sent Date

# %%
def get_action_date(row):
    status = row['Status']
    
    # Map status to the corresponding column name
    if status == 'CV Sent':
        return row['CV Sent Date']
    elif status == '1st Interview':
        return row['1st_Interview Date']
    elif status == '2nd Interview':
        return row['2nd_Interview Date']
    elif status == '3rd Interview':
        return row['3rd_Interview Date']
    elif status == '4th Interview':
        return row['4th_Interview Date']
    else:
        return pd.NaT # Return "Not a Time" for unknown statuses

# --- Apply the Function ---
merged_cv_sent_status['Action Date'] = merged_cv_sent_status.apply(get_action_date, axis=1)

# %%
# Drop the N/A rows in the status
merged_cv_sent_status = merged_cv_sent_status[(merged_cv_sent_status.Status != 'N/A') & (merged_cv_sent_status.Status != 'Rejected') & (merged_cv_sent_status.Status != 'Offer')]

merged_cv_sent_status['Status'].value_counts()
# Out:
# Status
# 1st Interview    108
# CV Sent           91
# 2nd Interview     55
# 4th Interview     31
# 3rd Interview     26
# Name: count, dtype: int64

# %%
# Drop the support columns
merged_cv_sent_status = merged_cv_sent_status.drop(columns = ['Interview_1st', 'Interview_2nd', 'Interview_3rd', 'Interview_4th', 'Rejected', 'Offer', 
                                                              '1st_Interview Date', '2nd_Interview Date', '3rd_Interview Date', '4th_Interview Date'])

# %%
display(merged_cv_sent_status)
# Out:
#       Job ID              Owner          Company  \
# 19       196        Max Hogarth         Blockaid
# 21       196        Ben Clifton         Blockaid
# 23       196        Ben Clifton         Blockaid
# 32       274       Brad Houston         Blockaid
# 38       416        Max Hogarth   Prime Security
# ...      ...                ...              ...
# 1474     870        Max Hogarth  Native Security
# 1475     871      Georgia Price     LaunchDarkly
# 1476     871  Jordan Goodenough     LaunchDarkly
# 1477     871   Samson Abodunrin     LaunchDarkly
# 1478     873         James Cato       CodeRabbit
#
#                                       Job Title CV Sent Date  \
# 19       Enterprise Account Executive (Fintech)   2025-12-17
# 21       Enterprise Account Executive (Fintech)   2025-11-04
# 23       Enterprise Account Executive (Fintech)   2025-11-26
# 32                   Senior Sales Engineer (US)   2025-11-12
# 38                            Account Executive   2025-12-05
# ...                                         ...          ...
# 1474  Enterprise Account Executive (North-East)   2025-12-17
# 1475                           Strategic AE U.S   2025-12-19
# 1476                           Strategic AE U.S   2025-12-18
# 1477                           Strategic AE U.S   2025-12-19
# 1478                        VP Enterprise Sales   2025-12-18
#
#              Candidate         Status Action Date
# 19       Jacob Neuhard        CV Sent  2025-12-17
# 21     Madyson Almeida  2nd Interview  2025-12-03
# 23          Mike Gomez  1st Interview  2025-12-01
# 32       Silja Petasch  1st Interview  2025-11-13
# 38         David Chase        CV Sent  2025-12-05
# ...                ...            ...         ...
# 1474        Rich Kroll        CV Sent  2025-12-17
# 1475       Dan DiPalma        CV Sent  2025-12-19
# 1476     Paul Plofchan        CV Sent  2025-12-18
# 1477  WILLIAM WOLLISON        CV Sent  2025-12-19
# 1478      Andrew Sweet  2nd Interview  2025-12-22
#
# [311 rows x 8 columns]

# %% [markdown]
# ## Export the in-play candidates for the recruiters

# %%
owners_list = merged_cv_sent_status['Owner'].dropna().unique()

merged_cv_sent_status['Action Date'].dt.floor('d')

# Create a folder to keep things organised
output_folder = 'Consultant_Active_Reports'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
for owner in owners_list:
    # 1. Filter for this specific owner
    owner_data = merged_cv_sent_status[merged_cv_sent_status['Owner'] == owner].copy()
    
    # 2. Sort by Job ID (Ascending)
    owner_data = owner_data.sort_values(by='Job ID', ascending=True)
    
    # 3. Select clean columns for the consultant
    export_cols = ['Job ID', 'Company', 'Job Title', 'Candidate', 'Status']
    final_export = owner_data[export_cols]
    
    # 4. Define Filename (Clean the name to avoid file errors)
    clean_owner_name = str(owner).replace(" ", "_").replace("/", "-")
    filename = f"{output_folder}/Active_Candidates_{clean_owner_name}.csv"
    
    # 5. Export to csv
    final_export.to_csv(filename, index=False)
    
    print(f"Exported: {filename} ({len(final_export)} candidates)")

print("\n--- ALL EXPORTS COMPLETE ---")
# Out:
# Exported: Consultant_Active_Reports/Active_Candidates_Max_Hogarth.csv (27 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ben_Clifton.csv (23 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Brad_Houston.csv (33 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Jordan_Goodenough.csv (25 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Joe_Marron.csv (22 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Gabriel_Inema.csv (18 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ada_Sitnik.csv (9 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Weronika_Nazarko.csv (15 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Georgia_Price.csv (9 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Samson_Abodunrin.csv (24 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Lilly_Tyler.csv (10 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Monie_Rogers.csv (10 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Nick_Chaplin.csv (15 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Whipp.csv (15 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Harry_Thornton.csv (4 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Cato.csv (9 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Sam_Rudston.csv (21 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Charlotte_Wells.csv (10 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Connor_Cook.csv (3 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Annalisa_Girgenti.csv (2 candidates)
#
# --- ALL EXPORTS COMPLETE ---
