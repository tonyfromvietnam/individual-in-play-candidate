# %%
# !pip install plotly

import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import os

# Set a clean, modern default theme for all our plots
pio.templates.default = "plotly_white"

print("Libraries imported successfully.")
# Out:
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (25.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Libraries imported successfully.

# %% [markdown]
# ## Import the Data (CVs Sent, 1st interview, Placements, Rejected)

# %% [markdown]
# ### CVs Sent

# %%
# CV Sent dataset
cv_sents = pd.read_csv('CVs Sent (Last 90 Days).csv')

# First 5 rows
display(cv_sents.head())
# Out:
#    ﻿"Job ID"     Job Owner Created Date           Owner Group   Company  \
# 0        196  Brad Houston   24/09/2025     Max Hogarth  EMEA  Blockaid
# 1        196  Brad Houston   02/10/2025     Max Hogarth  EMEA  Blockaid
# 2        196  Brad Houston   05/10/2025    Brad Houston  EMEA  Blockaid
# 3        196  Brad Houston   09/10/2025     Max Hogarth  EMEA  Blockaid
# 4        196  Brad Houston   14/10/2025  Harry Thornton  EMEA  Blockaid
#
#                                 Job Title Job Priority         Candidate  \
# 0  Enterprise Account Executive (Fintech)          NaN         Nik Lulla
# 1  Enterprise Account Executive (Fintech)          NaN  Michael Canfield
# 2  Enterprise Account Executive (Fintech)          NaN     Hassan Makiya
# 3  Enterprise Account Executive (Fintech)          NaN     DEREK ORGERON
# 4  Enterprise Account Executive (Fintech)          NaN        STONE GODI
#
#                       Source  Time to Send  CV Sent ID
# 0  LinkedIn Recruiter Inmail           399        4467
# 1                   Bullhorn           407        4590
# 2        LinkedIn Job Advert           410        4609
# 3  LinkedIn Recruiter Inmail           414        4667
# 4                   Referral           419        4718

# %% [markdown]
# ### 1st interviews

# %%
# Interviews dataset
first_interviews = pd.read_csv('1st Interviews (Last 90 Days).csv')

# First 5 rows
display(first_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date           Owner Group     Company  \
# 0      18/09/2025     23/09/2025      James Cato    US  CodeRabbit
# 1      18/09/2025     18/09/2025      James Cato    US  CodeRabbit
# 2      18/09/2025     18/09/2025      James Cato    US  CodeRabbit
# 3      18/09/2025     18/09/2025    Monie Rogers  EMEA       Dash0
# 4      18/09/2025     23/09/2025  Harry Thornton  EMEA   PointFive
#
#                    Job Title Job Priority         Candidate Client Contact  \
# 0                    AE West          Hot        Fred Stahl            NaN
# 1  Commercial AE x5 Bay Area          Hot      Ryan Manseau            NaN
# 2  Commercial AE x5 Bay Area          Hot      Ryan Manseau            NaN
# 3          Commercial AE NYC          Hot     Emisael Lopez            NaN
# 4                    VP EMEA          Hot  Rodrigo DeCossio            NaN
#
#      Job Type Interview Type CRM Interview Type                     Source  \
# 0  Contingent  1st Interview      1st Interview                   Bullhorn
# 1  Contingent  1st Interview      1st Interview  LinkedIn Recruiter Inmail
# 2  Contingent  1st Interview      1st Interview  LinkedIn Recruiter Inmail
# 3  Contingent  1st Interview      1st Interview           LinkedIn Message
# 4  Contingent  1st Interview      1st Interview                   Referral
#
#      Job Owner  Job ID  Interview ID
# 0   James Cato     587         17538
# 1   James Cato     687         17539
# 2   James Cato     687         17541
# 3   Joe Marron     617         17513
# 4  James Whipp     677         17517

# %% [markdown]
# ### 2nd interviews

# %%
# 2nd interviews dataset
second_interviews = pd.read_csv('2nd Interviews (Last 90 Days).csv')

# First 5 rows
display(second_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date         Owner Group          Company  \
# 0      19/09/2025     25/09/2025  Nick Chaplin  EMEA            Dash0
# 1      19/09/2025     19/09/2025    Ada Sitnik  EMEA  Legion Security
# 2      19/09/2025     19/09/2025    Ada Sitnik  EMEA  Legion Security
# 3      19/09/2025     08/09/2025    Joe Marron  EMEA        Honeycomb
# 4      19/09/2025     18/09/2025    Joe Marron  EMEA        Honeycomb
#
#                      Job Title Job Priority      Candidate Client Contact  \
# 0        Enterprise AE Germany          Hot  Thomas  Huber            NaN
# 1          Sales Engineer (US)          NaN     Megan Zhou            NaN
# 2          Sales Engineer (US)          NaN    Thomas Keck            NaN
# 3  Senior SDR (German Speaker)          Hot      Gwen Wons   Matt  Nelson
# 4              Strategic AE UK          Hot    Simon Price   Matt  Nelson
#
#           Job Type     Interview Type CRM Interview Type  \
# 0       Contingent  Further Interview      2nd Interview
# 1  Committed Spend  Further Interview      2nd Interview
# 2  Committed Spend  Further Interview      2nd Interview
# 3       Contingent  Further Interview      2nd Interview
# 4       Contingent  Further Interview      2nd Interview
#
#                       Source    Job Owner  Job ID  Interview ID
# 0     Email & Text follow up   Joe Marron     616         17542
# 1  LinkedIn Recruiter Inmail  James Whipp     580         17545
# 2  LinkedIn Recruiter Inmail  James Whipp     580         17546
# 3  LinkedIn Recruiter Inmail   Joe Marron     654         17551
# 4                   Bullhorn   Joe Marron     653         17550

# %% [markdown]
# ### 3rd interviews

# %%
# Interviews dataset
third_interviews = pd.read_csv('3rd Interviews (Last 90 Days).csv')

# First 5 rows
display(third_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date              Owner Group         Company  \
# 0      19/09/2025     10/09/2025         Joe Marron  EMEA       Honeycomb
# 1      19/09/2025     19/09/2025       Monie Rogers  EMEA      CodeRabbit
# 2      21/09/2025     18/09/2025  Jordan Goodenough  EMEA  Oasis Security
# 3      21/09/2025     19/09/2025  Jordan Goodenough  EMEA       UnifyApps
# 4      21/09/2025     24/09/2025  Jordan Goodenough  EMEA    Cognition AI
#
#                                      Job Title Job Priority      Candidate  \
# 0                  Senior SDR (German Speaker)          Hot      Gwen Wons
# 1                                      AE East          Hot      Jack King
# 2  Enterprise Account Executive (NYC Metro P1)          Hot     Matt Tower
# 3              UnifyApps - Solutions Architect          Hot  Waseem Bhatti
# 4            Enterprise Account Executive (US)          NaN   Chris Jensen
#
#    Client Contact    Job Type     Interview Type CRM Interview Type  \
# 0    Matt  Nelson  Contingent  Further Interview      3rd Interview
# 1             NaN  Contingent  Further Interview      3rd Interview
# 2  Nick Oberhuber  Contingent  Further Interview      3rd Interview
# 3  Colin Callahan  Contingent  Further Interview      3rd Interview
# 4     David Morse  Contingent  Further Interview      3rd Interview
#
#                       Source          Job Owner  Job ID  Interview ID
# 0  LinkedIn Recruiter Inmail         Joe Marron     654         17552
# 1  LinkedIn Recruiter Inmail         James Cato     588         17555
# 2                   Bullhorn     Harry Thornton     180         17601
# 3  LinkedIn Recruiter Inmail  Jordan Goodenough     668         17599
# 4                   Bullhorn  Annalisa Girgenti     484         17603

# %% [markdown]
# ### 4th interviews

# %%
# Interviews dataset
fourth_interviews = pd.read_csv('4th Interviews (Last 90 Days).csv')

# First 5 rows
display(fourth_interviews.tail())
# Out:
#     ﻿"Created Date" Interview Date             Owner Group           Company  \
# 128      15/12/2025     12/12/2025       Ben Clifton  EMEA          Blockaid
# 129      15/12/2025     17/12/2025  Weronika Nazarko  EMEA         Blink Ops
# 130      15/12/2025     16/12/2025      Nick Chaplin  EMEA   Energy Robotics
# 131      16/12/2025     16/12/2025        James Cato    US  Redwood Software
# 132      16/12/2025     16/12/2025      Nick Chaplin  EMEA   Energy Robotics
#
#                                  Job Title Job Priority       Candidate  \
# 128                        SDR (Singapore)          Hot   Dinie Mifdhal
# 129                      Sales Engineer UK          Hot      Adam Evans
# 130                              SDR Dubai          Hot        Jad Akel
# 131  Enterprise AE US (Finance Automation)          Hot  David McDonald
# 132                              SDR Dubai          Hot        Jad Akel
#
#       Client Contact    Job Type     Interview Type CRM Interview Type  \
# 128              NaN  Contingent  Further Interview      4th Interview
# 129  Aaron Beveridge  Contingent  Further Interview      4th Interview
# 130              NaN  Contingent  Further Interview      4th Interview
# 131              NaN  Contingent  Further Interview      4th Interview
# 132              NaN  Contingent  Further Interview      4th Interview
#
#                         Source          Job Owner  Job ID  Interview ID
# 128     Email & Text follow up       Brad Houston     757         20355
# 129  LinkedIn Recruiter Inmail       Brad Houston     663         20358
# 130                Sales Robot  Annalisa Girgenti     778         20375
# 131  LinkedIn Recruiter Inmail         James Cato     795         20391
# 132                Sales Robot  Annalisa Girgenti     778         20394

# %% [markdown]
# ### Rejected Candidates

# %%
# Rejects dataset
rejects = pd.read_csv('Rejected Candidates (Last 90 Days).csv')

rejects.rename(columns={'﻿"Job ID"' : 'Job ID'}, inplace=True)

rejects = rejects[['Job ID', 'Candidate']]

# First 5 rows
display(rejects.head())
# Out:
#    Job ID       Candidate
# 0     110    Mark Ghannam
# 1     110  Matthias Funke
# 2     110       Dan Croft
# 3     110   Vyas Adhikari
# 4     110       Miguel L.

# %% [markdown]
# ### Offers

# %%
# Offers dataset
offers = pd.read_csv('Offers (Last 90 Days).csv')

offers = offers[['Job ID', 'Candidate']]

# Last 5 rows
display(offers.tail())
# Out:
#     Job ID         Candidate
# 62     656  Ryan Finkelstein
# 63     751      Tiffany Cole
# 64     777       Itai Heller
# 65     776      Daniel Smith
# 66     428       Caitlin Ray

# %% [markdown]
# ## Re-structure the data, changing their fields

# %%
# Rename the Kpi Date columns to CV Sent Date, change that to datetime type
cv_sents.rename(columns={'Created Date' : 'CV Sent Date', '﻿"Job ID"' : 'Job ID'}, inplace=True)

# Change the CV Sent Date to datetime type
cv_sents['CV Sent Date'] = pd.to_datetime(cv_sents['CV Sent Date'], format='%d/%m/%Y')
cv_sents = cv_sents[['Job ID', 'Owner', 'Company', 'Job Title', 'CV Sent Date', 'Candidate']]

# Display the new dataset
cv_sents.head()
# Out:
#    Job ID           Owner   Company                               Job Title  \
# 0     196     Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 1     196     Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 2     196    Brad Houston  Blockaid  Enterprise Account Executive (Fintech)
# 3     196     Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 4     196  Harry Thornton  Blockaid  Enterprise Account Executive (Fintech)
#
#   CV Sent Date         Candidate
# 0   2025-09-24         Nik Lulla
# 1   2025-10-02  Michael Canfield
# 2   2025-10-05     Hassan Makiya
# 3   2025-10-09     DEREK ORGERON
# 4   2025-10-14        STONE GODI

# %%
# Rename the Kpi Date columns to Interview Date, change that to datetime type
first_interviews.rename(columns={'Interview Date' : '1st_Interview Date'}, inplace=True)
second_interviews.rename(columns={'Interview Date' : '2nd_Interview Date'}, inplace=True)
third_interviews.rename(columns={'Interview Date' : '3rd_Interview Date'}, inplace=True)
fourth_interviews.rename(columns={'Interview Date' : '4th_Interview Date'}, inplace=True)

# Change the Create Date to datetime type
first_interviews['1st_Interview Date'] = pd.to_datetime(first_interviews['1st_Interview Date'], format='%d/%m/%Y')
first_interviews = first_interviews[['Job ID', '1st_Interview Date', 'Candidate']]

second_interviews['2nd_Interview Date'] = pd.to_datetime(second_interviews['2nd_Interview Date'], format='%d/%m/%Y')
second_interviews = second_interviews[['Job ID', '2nd_Interview Date', 'Candidate']]

third_interviews['3rd_Interview Date'] = pd.to_datetime(third_interviews['3rd_Interview Date'], format='%d/%m/%Y')
third_interviews = third_interviews[['Job ID', '3rd_Interview Date', 'Candidate']]

fourth_interviews['4th_Interview Date'] = pd.to_datetime(fourth_interviews['4th_Interview Date'], format='%d/%m/%Y')
fourth_interviews = fourth_interviews[['Job ID', '4th_Interview Date','Candidate']]

# %% [markdown]
# ## Create a few helper columns to get the status of CVs Sent to Clients

# %%
# Apply helper columns to get the status of CVs
first_interviews['Interview_1st'] = True
second_interviews['Interview_2nd'] = True
third_interviews['Interview_3rd'] = True
fourth_interviews['Interview_4th'] = True
offers['Offer'] = True
rejects['Rejected'] = True

# %%
first_interviews.head()
# Out:
#    Job ID 1st_Interview Date         Candidate  Interview_1st
# 0     587         2025-09-23        Fred Stahl           True
# 1     687         2025-09-18      Ryan Manseau           True
# 2     687         2025-09-18      Ryan Manseau           True
# 3     617         2025-09-18     Emisael Lopez           True
# 4     677         2025-09-23  Rodrigo DeCossio           True

# %% [markdown]
# ### Merge the CV records with the interviews

# %%
# Merge the CV record with the 1st interview record
merged_cv_sent_status = cv_sents.merge(
    first_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 2nd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    second_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 3rd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    third_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 4th interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    fourth_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the offers record
merged_cv_sent_status = merged_cv_sent_status.merge(
    offers,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the rejected record
merged_cv_sent_status = merged_cv_sent_status.merge(
    rejects,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Print the final list
display(merged_cv_sent_status)
# Out:
#       Job ID          Owner    Company                          Job Title  \
# 0        110            NaN        NaN                                NaN
# 1        110            NaN        NaN                                NaN
# 2        110            NaN        NaN                                NaN
# 3        110            NaN        NaN                                NaN
# 4        110            NaN        NaN                                NaN
# ...      ...            ...        ...                                ...
# 1557     855  Gabriel Inema     Laurel  Customer Success Manager New York
# 1558     857   Brad Houston  Adaptive6            Sales Engineer (Israel)
# 1559     857   Brad Houston  Adaptive6            Sales Engineer (Israel)
# 1560     857   Brad Houston  Adaptive6            Sales Engineer (Israel)
# 1561     858     Joe Marron        Rox                             SDR SF
#
#      CV Sent Date         Candidate 1st_Interview Date Interview_1st  \
# 0             NaT         Ali Sezer                NaT           NaN
# 1             NaT         Dan Croft                NaT           NaN
# 2             NaT      Mark Ghannam                NaT           NaN
# 3             NaT    Matthias Funke                NaT           NaN
# 4             NaT         Miguel L.                NaT           NaN
# ...           ...               ...                ...           ...
# 1557   2025-12-15  Anouska Khimasia                NaT           NaN
# 1558   2025-12-10    Barak Abekasis                NaT           NaN
# 1559   2025-12-10       Nathan Hart         2025-12-12          True
# 1560   2025-12-11  Rotem Froimovici         2025-12-15          True
# 1561   2025-12-11    Victor Ermolin                NaT           NaN
#
#      2nd_Interview Date Interview_2nd 3rd_Interview Date Interview_3rd  \
# 0                   NaT           NaN                NaT           NaN
# 1                   NaT           NaN                NaT           NaN
# 2                   NaT           NaN                NaT           NaN
# 3                   NaT           NaN                NaT           NaN
# 4                   NaT           NaN                NaT           NaN
# ...                 ...           ...                ...           ...
# 1557                NaT           NaN                NaT           NaN
# 1558                NaT           NaN                NaT           NaN
# 1559                NaT           NaN                NaT           NaN
# 1560                NaT           NaN                NaT           NaN
# 1561                NaT           NaN                NaT           NaN
#
#      4th_Interview Date Interview_4th Offer Rejected
# 0                   NaT           NaN   NaN     True
# 1                   NaT           NaN   NaN     True
# 2                   NaT           NaN   NaN     True
# 3                   NaT           NaN   NaN     True
# 4                   NaT           NaN   NaN     True
# ...                 ...           ...   ...      ...
# 1557                NaT           NaN   NaN      NaN
# 1558                NaT           NaN   NaN      NaN
# 1559                NaT           NaN   NaN      NaN
# 1560                NaT           NaN   NaN      NaN
# 1561                NaT           NaN   NaN      NaN
#
# [1562 rows x 16 columns]

# %%
merged_cv_sent_status.head()
# Out:
#    Job ID Owner Company Job Title CV Sent Date       Candidate  \
# 0     110   NaN     NaN       NaN          NaT       Ali Sezer
# 1     110   NaN     NaN       NaN          NaT       Dan Croft
# 2     110   NaN     NaN       NaN          NaT    Mark Ghannam
# 3     110   NaN     NaN       NaN          NaT  Matthias Funke
# 4     110   NaN     NaN       NaN          NaT       Miguel L.
#
#   1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0                NaT           NaN                NaT           NaN
# 1                NaT           NaN                NaT           NaN
# 2                NaT           NaN                NaT           NaN
# 3                NaT           NaN                NaT           NaN
# 4                NaT           NaN                NaT           NaN
#
#   3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                NaT           NaN                NaT           NaN   NaN
# 1                NaT           NaN                NaT           NaN   NaN
# 2                NaT           NaN                NaT           NaN   NaN
# 3                NaT           NaN                NaT           NaN   NaN
# 4                NaT           NaN                NaT           NaN   NaN
#
#   Rejected
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %% [markdown]
# ### Change the status of the candidates

# %%
def determine_status(row):
    # 1. Highest Priority: Is it Rejected?
    if row['Rejected'] == True:
        return 'Rejected'
    
    # 2. Next Priority: Is there an Offer?
    elif row['Offer'] == True:
        return 'Offer'
    
    # 3. Check Interview Stages (Backwards from latest)
    elif row['Interview_4th'] == True:
        return '4th Interview'
    elif row['Interview_3rd'] == True:
        return '3rd Interview'
    elif row['Interview_2nd'] == True:
        return '2nd Interview'
    elif row['Interview_1st'] == True:
        return '1st Interview'
    
    # 4. Default
    else:
        return 'CV Sent'

# Apply it to the DataFrame
merged_cv_sent_status['Status'] = merged_cv_sent_status.apply(determine_status, axis=1)

display(merged_cv_sent_status)
# Out:
#       Job ID          Owner    Company                          Job Title  \
# 0        110            NaN        NaN                                NaN
# 1        110            NaN        NaN                                NaN
# 2        110            NaN        NaN                                NaN
# 3        110            NaN        NaN                                NaN
# 4        110            NaN        NaN                                NaN
# ...      ...            ...        ...                                ...
# 1557     855  Gabriel Inema     Laurel  Customer Success Manager New York
# 1558     857   Brad Houston  Adaptive6            Sales Engineer (Israel)
# 1559     857   Brad Houston  Adaptive6            Sales Engineer (Israel)
# 1560     857   Brad Houston  Adaptive6            Sales Engineer (Israel)
# 1561     858     Joe Marron        Rox                             SDR SF
#
#      CV Sent Date         Candidate 1st_Interview Date Interview_1st  \
# 0             NaT         Ali Sezer                NaT           NaN
# 1             NaT         Dan Croft                NaT           NaN
# 2             NaT      Mark Ghannam                NaT           NaN
# 3             NaT    Matthias Funke                NaT           NaN
# 4             NaT         Miguel L.                NaT           NaN
# ...           ...               ...                ...           ...
# 1557   2025-12-15  Anouska Khimasia                NaT           NaN
# 1558   2025-12-10    Barak Abekasis                NaT           NaN
# 1559   2025-12-10       Nathan Hart         2025-12-12          True
# 1560   2025-12-11  Rotem Froimovici         2025-12-15          True
# 1561   2025-12-11    Victor Ermolin                NaT           NaN
#
#      2nd_Interview Date Interview_2nd 3rd_Interview Date Interview_3rd  \
# 0                   NaT           NaN                NaT           NaN
# 1                   NaT           NaN                NaT           NaN
# 2                   NaT           NaN                NaT           NaN
# 3                   NaT           NaN                NaT           NaN
# 4                   NaT           NaN                NaT           NaN
# ...                 ...           ...                ...           ...
# 1557                NaT           NaN                NaT           NaN
# 1558                NaT           NaN                NaT           NaN
# 1559                NaT           NaN                NaT           NaN
# 1560                NaT           NaN                NaT           NaN
# 1561                NaT           NaN                NaT           NaN
#
#      4th_Interview Date Interview_4th Offer Rejected         Status
# 0                   NaT           NaN   NaN     True       Rejected
# 1                   NaT           NaN   NaN     True       Rejected
# 2                   NaT           NaN   NaN     True       Rejected
# 3                   NaT           NaN   NaN     True       Rejected
# 4                   NaT           NaN   NaN     True       Rejected
# ...                 ...           ...   ...      ...            ...
# 1557                NaT           NaN   NaN      NaN        CV Sent
# 1558                NaT           NaN   NaN      NaN        CV Sent
# 1559                NaT           NaN   NaN      NaN  1st Interview
# 1560                NaT           NaN   NaN      NaN  1st Interview
# 1561                NaT           NaN   NaN      NaN        CV Sent
#
# [1562 rows x 17 columns]

# %% [markdown]
# ### Add the column of Action Date - Interview/CV Sent Date

# %%
def get_action_date(row):
    status = row['Status']
    
    # Map status to the corresponding column name
    if status == 'CV Sent':
        return row['CV Sent Date']
    elif status == '1st Interview':
        return row['1st_Interview Date']
    elif status == '2nd Interview':
        return row['2nd_Interview Date']
    elif status == '3rd Interview':
        return row['3rd_Interview Date']
    elif status == '4th Interview':
        return row['4th_Interview Date']
    else:
        return pd.NaT # Return "Not a Time" for unknown statuses

# --- Apply the Function ---
merged_cv_sent_status['Action Date'] = merged_cv_sent_status.apply(get_action_date, axis=1)

# %%
# Drop the N/A rows in the status
merged_cv_sent_status = merged_cv_sent_status[(merged_cv_sent_status.Status != 'N/A') & (merged_cv_sent_status.Status != 'Rejected') & (merged_cv_sent_status.Status != 'Offer')]

merged_cv_sent_status['Status'].value_counts()
# Out:
# Status
# 1st Interview    118
# CV Sent           88
# 2nd Interview     59
# 4th Interview     33
# 3rd Interview     32
# Name: count, dtype: int64

# %%
# Drop the support columns
merged_cv_sent_status = merged_cv_sent_status.drop(columns = ['Interview_1st', 'Interview_2nd', 'Interview_3rd', 'Interview_4th', 'Rejected', 'Offer', 
                                                              '1st_Interview Date', '2nd_Interview Date', '3rd_Interview Date', '4th_Interview Date'])

# %%
display(merged_cv_sent_status)
# Out:
#       Job ID             Owner    Company  \
# 12       196       Ben Clifton   Blockaid
# 15       196       Ben Clifton   Blockaid
# 20       196  Samson Abodunrin   Blockaid
# 22       196       Ben Clifton   Blockaid
# 24       196       Ben Clifton   Blockaid
# ...      ...               ...        ...
# 1557     855     Gabriel Inema     Laurel
# 1558     857      Brad Houston  Adaptive6
# 1559     857      Brad Houston  Adaptive6
# 1560     857      Brad Houston  Adaptive6
# 1561     858        Joe Marron        Rox
#
#                                    Job Title CV Sent Date         Candidate  \
# 12    Enterprise Account Executive (Fintech)   2025-12-16    Connor Yakushi
# 15    Enterprise Account Executive (Fintech)   2025-11-10     Dennis Coombs
# 20    Enterprise Account Executive (Fintech)   2025-12-05     Jason Fulwood
# 22    Enterprise Account Executive (Fintech)   2025-11-04   Madyson Almeida
# 24    Enterprise Account Executive (Fintech)   2025-11-26        Mike Gomez
# ...                                      ...          ...               ...
# 1557       Customer Success Manager New York   2025-12-15  Anouska Khimasia
# 1558                 Sales Engineer (Israel)   2025-12-10    Barak Abekasis
# 1559                 Sales Engineer (Israel)   2025-12-10       Nathan Hart
# 1560                 Sales Engineer (Israel)   2025-12-11  Rotem Froimovici
# 1561                                  SDR SF   2025-12-11    Victor Ermolin
#
#              Status Action Date
# 12          CV Sent  2025-12-16
# 15    3rd Interview  2025-12-16
# 20          CV Sent  2025-12-05
# 22    2nd Interview  2025-12-03
# 24    1st Interview  2025-12-01
# ...             ...         ...
# 1557        CV Sent  2025-12-15
# 1558        CV Sent  2025-12-10
# 1559  1st Interview  2025-12-12
# 1560  1st Interview  2025-12-15
# 1561        CV Sent  2025-12-11
#
# [330 rows x 8 columns]

# %% [markdown]
# ## Export the in-play candidates for the recruiters

# %%
owners_list = merged_cv_sent_status['Owner'].dropna().unique()

merged_cv_sent_status['Action Date'].dt.floor('d')

# Create a folder to keep things organised
output_folder = 'Consultant_Active_Reports'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
for owner in owners_list:
    # 1. Filter for this specific owner
    owner_data = merged_cv_sent_status[merged_cv_sent_status['Owner'] == owner].copy()
    
    # 2. Sort by Job ID (Ascending)
    owner_data = owner_data.sort_values(by='Job ID', ascending=True)
    
    # 3. Select clean columns for the consultant
    export_cols = ['Job ID', 'Company', 'Job Title', 'Candidate', 'Status']
    final_export = owner_data[export_cols]
    
    # 4. Define Filename (Clean the name to avoid file errors)
    clean_owner_name = str(owner).replace(" ", "_").replace("/", "-")
    filename = f"{output_folder}/Active_Candidates_{clean_owner_name}.csv"
    
    # 5. Export to csv
    final_export.to_csv(filename, index=False)
    
    print(f"Exported: {filename} ({len(final_export)} candidates)")

print("\n--- ALL EXPORTS COMPLETE ---")
# Out:
# Exported: Consultant_Active_Reports/Active_Candidates_Ben_Clifton.csv (27 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Samson_Abodunrin.csv (29 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Brad_Houston.csv (32 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Max_Hogarth.csv (23 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Jordan_Goodenough.csv (20 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Joe_Marron.csv (27 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ada_Sitnik.csv (13 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Weronika_Nazarko.csv (20 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Georgia_Price.csv (6 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Gabriel_Inema.csv (13 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Lilly_Tyler.csv (9 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Monie_Rogers.csv (11 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Nick_Chaplin.csv (12 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Sam_Rudston.csv (24 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Whipp.csv (17 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Harry_Thornton.csv (7 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Cato.csv (22 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Charlotte_Wells.csv (5 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Connor_Cook.csv (6 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Annalisa_Girgenti.csv (2 candidates)
#
# --- ALL EXPORTS COMPLETE ---
