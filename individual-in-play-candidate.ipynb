# %% [markdown]
# # Individual in-play candidates

# %%
# !pip install plotly

import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import os

# Set a clean, modern default theme for all our plots
pio.templates.default = "plotly_white"

print("Libraries imported successfully.")
# Out:
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (25.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Libraries imported successfully.

# %% [markdown]
# ## Import the Data (CVs Sent, 1st interview, Placements, Rejected)

# %% [markdown]
# ### CVs Sent

# %%
# CV Sent dataset
cv_sents = pd.read_csv('CVs Sent (Last 90 Days).csv')

# First 5 rows
display(cv_sents.head())
# Out:
#    ﻿"Job ID"     Job Owner Created Date           Owner Group   Company  \
# 0        196  Brad Houston   24/09/2025     Max Hogarth  EMEA  Blockaid
# 1        196  Brad Houston   02/10/2025     Max Hogarth  EMEA  Blockaid
# 2        196  Brad Houston   05/10/2025    Brad Houston  EMEA  Blockaid
# 3        196  Brad Houston   09/10/2025     Max Hogarth  EMEA  Blockaid
# 4        196  Brad Houston   14/10/2025  Harry Thornton  EMEA  Blockaid
#
#                                 Job Title Job Priority         Candidate  \
# 0  Enterprise Account Executive (Fintech)          NaN         Nik Lulla
# 1  Enterprise Account Executive (Fintech)          NaN  Michael Canfield
# 2  Enterprise Account Executive (Fintech)          NaN     Hassan Makiya
# 3  Enterprise Account Executive (Fintech)          NaN     DEREK ORGERON
# 4  Enterprise Account Executive (Fintech)          NaN        STONE GODI
#
#                       Source  Time to Send  CV Sent ID
# 0  LinkedIn Recruiter Inmail           399        4467
# 1                   Bullhorn           407        4590
# 2        LinkedIn Job Advert           410        4609
# 3  LinkedIn Recruiter Inmail           414        4667
# 4                   Referral           419        4718

# %% [markdown]
# ### 1st interviews

# %%
# Interviews dataset
first_interviews = pd.read_csv('1st Interviews (Last 90 Days).csv')

# First 5 rows
display(first_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date             Owner Group         Company  \
# 0      21/09/2025     21/09/2025      Brad Houston  EMEA        Blockaid
# 1      22/09/2025     22/09/2025       James Whipp  EMEA       PointFive
# 2      22/09/2025     22/09/2025      Monie Rogers  EMEA           Dash0
# 3      22/09/2025     23/09/2025  Weronika Nazarko  EMEA  Oasis Security
# 4      22/09/2025     25/09/2025  Weronika Nazarko  EMEA  Oasis Security
#
#                                Job Title Job Priority               Candidate  \
# 0     CS2 Blockaid - RevOps Manager (NY)         Warm        Christian Powers
# 1      Channel & Alliances Director - UK          Hot              Roger Nash
# 2                Commercial AE Amsterdam          Hot  Christopher Tengstrand
# 3                   TAM (East + Central)          Hot           Jerry Johanes
# 4  Senior Solution Architect (US/Canada)          Hot          Sumeet Ramnani
#
#    Client Contact         Job Type Interview Type CRM Interview Type  \
# 0   Glenn Rachlin  Committed Spend  1st Interview      1st Interview
# 1             NaN       Contingent  1st Interview      1st Interview
# 2             NaN       Contingent  1st Interview      1st Interview
# 3  Danny Brickman       Contingent  1st Interview      1st Interview
# 4  Danny Brickman       Contingent  1st Interview      1st Interview
#
#                       Source     Job Owner  Job ID  Interview ID
# 0  LinkedIn Recruiter Inmail  Brad Houston     683         17619
# 1  LinkedIn Recruiter Inmail   James Whipp     661         17628
# 2  LinkedIn Recruiter Inmail    Joe Marron     622         17629
# 3  LinkedIn Recruiter Inmail  Brad Houston     577         17631
# 4  LinkedIn Recruiter Inmail  Brad Houston     679         17635

# %% [markdown]
# ### 2nd interviews

# %%
# 2nd interviews dataset
second_interviews = pd.read_csv('2nd Interviews (Last 90 Days).csv')

# First 5 rows
display(second_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date              Owner Group         Company  \
# 0      21/09/2025     17/09/2025  Jordan Goodenough  EMEA       UnifyApps
# 1      21/09/2025     18/09/2025  Jordan Goodenough  EMEA  Oasis Security
# 2      21/09/2025     22/09/2025  Jordan Goodenough  EMEA       UnifyApps
# 3      21/09/2025     17/09/2025  Jordan Goodenough  EMEA    Cognition AI
# 4      21/09/2025     19/09/2025  Jordan Goodenough  EMEA        Blockaid
#
#                                            Job Title Job Priority  \
# 0                    UnifyApps - Solutions Architect          Hot
# 1        Enterprise Account Executive (NYC Metro P1)          Hot
# 2           UnifyApps - Partner / Alliances Director          Hot
# 3                  Enterprise Account Executive (US)          NaN
# 4  CS2 - Blockaid - Enterprise Account Executive ...          NaN
#
#            Candidate  Client Contact    Job Type     Interview Type  \
# 0      Waseem Bhatti  Colin Callahan  Contingent  Further Interview
# 1         Matt Tower  Nick Oberhuber  Contingent  Further Interview
# 2  Kaleigh Dougherty  Colin Callahan  Contingent  Further Interview
# 3  Christopher Amata     David Morse  Contingent  Further Interview
# 4      Jaime Valadao   Glenn Rachlin  Contingent  Further Interview
#
#   CRM Interview Type                     Source          Job Owner  Job ID  \
# 0      2nd Interview  LinkedIn Recruiter Inmail  Jordan Goodenough     668
# 1      2nd Interview                   Bullhorn     Harry Thornton     180
# 2      2nd Interview           LinkedIn Message  Jordan Goodenough     657
# 3      2nd Interview  LinkedIn Recruiter Inmail  Annalisa Girgenti     484
# 4      2nd Interview                   Referral       Brad Houston     501
#
#    Interview ID
# 0         17598
# 1         17600
# 2         17602
# 3         17604
# 4         17605

# %% [markdown]
# ### 3rd interviews

# %%
# Interviews dataset
third_interviews = pd.read_csv('3rd Interviews (Last 90 Days).csv')

# First 5 rows
display(third_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date              Owner Group         Company  \
# 0      21/09/2025     18/09/2025  Jordan Goodenough  EMEA  Oasis Security
# 1      21/09/2025     19/09/2025  Jordan Goodenough  EMEA       UnifyApps
# 2      21/09/2025     24/09/2025  Jordan Goodenough  EMEA    Cognition AI
# 3      21/09/2025     21/09/2025   Samson Abodunrin  EMEA         Oscilar
# 4      21/09/2025     21/09/2025   Samson Abodunrin  EMEA   Safe Security
#
#                                      Job Title Job Priority  \
# 0  Enterprise Account Executive (NYC Metro P1)          Hot
# 1              UnifyApps - Solutions Architect          Hot
# 2            Enterprise Account Executive (US)          NaN
# 3                             MidMarket Leader          Hot
# 4                                     RVP- NYC          Hot
#
#            Candidate  Client Contact    Job Type     Interview Type  \
# 0         Matt Tower  Nick Oberhuber  Contingent  Further Interview
# 1      Waseem Bhatti  Colin Callahan  Contingent  Further Interview
# 2       Chris Jensen     David Morse  Contingent  Further Interview
# 3    Adam Navrozally             NaN  Contingent  Further Interview
# 4  Michael Goldstein             NaN  Contingent  Further Interview
#
#   CRM Interview Type                     Source          Job Owner  Job ID  \
# 0      3rd Interview                   Bullhorn     Harry Thornton     180
# 1      3rd Interview  LinkedIn Recruiter Inmail  Jordan Goodenough     668
# 2      3rd Interview                   Bullhorn  Annalisa Girgenti     484
# 3      3rd Interview           LinkedIn Message   Samson Abodunrin     666
# 4      3rd Interview     Email & Text follow up   Samson Abodunrin     608
#
#    Interview ID
# 0         17601
# 1         17599
# 2         17603
# 3         17608
# 4         17611

# %% [markdown]
# ### 4th interviews

# %%
# Interviews dataset
fourth_interviews = pd.read_csv('4th Interviews (Last 90 Days).csv')

# First 5 rows
display(fourth_interviews.tail())
# Out:
#     ﻿"Created Date" Interview Date             Owner Group     Company  \
# 140      19/12/2025     18/12/2025       Ben Clifton  EMEA    Blockaid
# 141      19/12/2025     22/12/2025      Monie Rogers  EMEA         Rox
# 142      19/12/2025     19/12/2025  Samson Abodunrin  EMEA  Antithesis
# 143      19/12/2025     17/12/2025        Joe Marron  EMEA   Honeycomb
# 144      19/12/2025     19/12/2025  Samson Abodunrin  EMEA      Impala
#
#               Job Title Job Priority       Candidate Client Contact  \
# 140     SDR (Singapore)          Hot   Dinie Mifdhal            NaN
# 141         ENT AE East          Hot     Graham Hill            NaN
# 142                 BDR          Hot      Ryan Lewis       Hao Guan
# 143     Strat AE U.S x4          Hot  Brian Saverino   Matt  Nelson
# 144  Head of Sales (NA)          Hot    Patrick Racy            NaN
#
#        Job Type     Interview Type CRM Interview Type                  Source  \
# 140  Contingent  Further Interview      4th Interview  Email & Text follow up
# 141  Contingent  Further Interview      4th Interview        LinkedIn Message
# 142  Contingent  Further Interview      4th Interview     LinkedIn Job Advert
# 143  Contingent  Further Interview      4th Interview                Bullhorn
# 144  Contingent  Further Interview      4th Interview        LinkedIn Message
#
#              Job Owner  Job ID  Interview ID
# 140       Brad Houston     757         20525
# 141         James Cato     721         20524
# 142   Samson Abodunrin     667         20540
# 143         Joe Marron     715         20544
# 144  Annalisa Girgenti     760         20548

# %% [markdown]
# ### Rejected Candidates

# %%
# Rejects dataset
rejects = pd.read_csv('Rejected Candidates (Last 90 Days).csv')

rejects.rename(columns={'﻿"Job ID"' : 'Job ID'}, inplace=True)

rejects = rejects[['Job ID', 'Candidate']]

# First 5 rows
display(rejects.head())
# Out:
#    Job ID       Candidate
# 0     110    Mark Ghannam
# 1     110  Matthias Funke
# 2     110       Dan Croft
# 3     110   Vyas Adhikari
# 4     110       Miguel L.

# %% [markdown]
# ### Offers

# %%
# Offers dataset
offers = pd.read_csv('Offers (Last 90 Days).csv')

offers = offers[['Job ID', 'Candidate']]

# Last 5 rows
display(offers.tail())
# Out:
#     Job ID       Candidate
# 72     782   Jamie Summers
# 73     795  David McDonald
# 74     739    Jacques Lane
# 75     806   PETER SIMMONS
# 76     594    Scott Murphy

# %% [markdown]
# ## Re-structure the data, changing their fields

# %%
# Rename the Kpi Date columns to CV Sent Date, change that to datetime type
cv_sents.rename(columns={'Created Date' : 'CV Sent Date', '﻿"Job ID"' : 'Job ID'}, inplace=True)

# Change the CV Sent Date to datetime type
cv_sents['CV Sent Date'] = pd.to_datetime(cv_sents['CV Sent Date'], format='%d/%m/%Y')
cv_sents = cv_sents[['Job ID', 'Owner', 'Company', 'Job Title', 'CV Sent Date', 'Candidate']]

# Display the new dataset
cv_sents.head()
# Out:
#    Job ID           Owner   Company                               Job Title  \
# 0     196     Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 1     196     Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 2     196    Brad Houston  Blockaid  Enterprise Account Executive (Fintech)
# 3     196     Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 4     196  Harry Thornton  Blockaid  Enterprise Account Executive (Fintech)
#
#   CV Sent Date         Candidate
# 0   2025-09-24         Nik Lulla
# 1   2025-10-02  Michael Canfield
# 2   2025-10-05     Hassan Makiya
# 3   2025-10-09     DEREK ORGERON
# 4   2025-10-14        STONE GODI

# %%
# Rename the Kpi Date columns to Interview Date, change that to datetime type
first_interviews.rename(columns={'Interview Date' : '1st_Interview Date'}, inplace=True)
second_interviews.rename(columns={'Interview Date' : '2nd_Interview Date'}, inplace=True)
third_interviews.rename(columns={'Interview Date' : '3rd_Interview Date'}, inplace=True)
fourth_interviews.rename(columns={'Interview Date' : '4th_Interview Date'}, inplace=True)

# Change the Create Date to datetime type
first_interviews['1st_Interview Date'] = pd.to_datetime(first_interviews['1st_Interview Date'], format='%d/%m/%Y')
first_interviews = first_interviews[['Job ID', '1st_Interview Date', 'Candidate']]

second_interviews['2nd_Interview Date'] = pd.to_datetime(second_interviews['2nd_Interview Date'], format='%d/%m/%Y')
second_interviews = second_interviews[['Job ID', '2nd_Interview Date', 'Candidate']]

third_interviews['3rd_Interview Date'] = pd.to_datetime(third_interviews['3rd_Interview Date'], format='%d/%m/%Y')
third_interviews = third_interviews[['Job ID', '3rd_Interview Date', 'Candidate']]

fourth_interviews['4th_Interview Date'] = pd.to_datetime(fourth_interviews['4th_Interview Date'], format='%d/%m/%Y')
fourth_interviews = fourth_interviews[['Job ID', '4th_Interview Date','Candidate']]

# %% [markdown]
# ## Create a few helper columns to get the status of CVs Sent to Clients

# %%
# Apply helper columns to get the status of CVs
first_interviews['Interview_1st'] = True
second_interviews['Interview_2nd'] = True
third_interviews['Interview_3rd'] = True
fourth_interviews['Interview_4th'] = True
offers['Offer'] = True
rejects['Rejected'] = True

# %%
first_interviews.head()
# Out:
#    Job ID 1st_Interview Date               Candidate  Interview_1st
# 0     683         2025-09-21        Christian Powers           True
# 1     661         2025-09-22              Roger Nash           True
# 2     622         2025-09-22  Christopher Tengstrand           True
# 3     577         2025-09-23           Jerry Johanes           True
# 4     679         2025-09-25          Sumeet Ramnani           True

# %% [markdown]
# ### Merge the CV records with the interviews

# %%
# Merge the CV record with the 1st interview record
merged_cv_sent_status = cv_sents.merge(
    first_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 2nd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    second_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 3rd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    third_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 4th interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    fourth_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the offers record
merged_cv_sent_status = merged_cv_sent_status.merge(
    offers,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the rejected record
merged_cv_sent_status = merged_cv_sent_status.merge(
    rejects,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Print the final list
display(merged_cv_sent_status)
# Out:
#       Job ID              Owner          Company  \
# 0        110                NaN              NaN
# 1        110                NaN              NaN
# 2        110                NaN              NaN
# 3        110                NaN              NaN
# 4        110                NaN              NaN
# ...      ...                ...              ...
# 1612     869       Brad Houston  Native Security
# 1613     870        Max Hogarth  Native Security
# 1614     871      Georgia Price     LaunchDarkly
# 1615     871  Jordan Goodenough     LaunchDarkly
# 1616     873         James Cato       CodeRabbit
#
#                                       Job Title CV Sent Date       Candidate  \
# 0                                           NaN          NaT       Ali Sezer
# 1                                           NaN          NaT       Dan Croft
# 2                                           NaN          NaT    Mark Ghannam
# 3                                           NaN          NaT  Matthias Funke
# 4                                           NaN          NaT       Miguel L.
# ...                                         ...          ...             ...
# 1612     Enterprise Account Executive (Chicago)   2025-12-17   Chris Gardner
# 1613  Enterprise Account Executive (North-East)   2025-12-17      Rich Kroll
# 1614                           Strategic AE U.S   2025-12-19     Dan DiPalma
# 1615                           Strategic AE U.S   2025-12-18   Paul Plofchan
# 1616                        VP Enterprise Sales   2025-12-18    Andrew Sweet
#
#      1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0                   NaT           NaN                NaT           NaN
# 1                   NaT           NaN                NaT           NaN
# 2                   NaT           NaN                NaT           NaN
# 3                   NaT           NaN                NaT           NaN
# 4                   NaT           NaN                NaT           NaN
# ...                 ...           ...                ...           ...
# 1612                NaT           NaN                NaT           NaN
# 1613                NaT           NaN                NaT           NaN
# 1614                NaT           NaN                NaT           NaN
# 1615                NaT           NaN                NaT           NaN
# 1616         2025-12-19          True                NaT           NaN
#
#      3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                   NaT           NaN                NaT           NaN   NaN
# 1                   NaT           NaN                NaT           NaN   NaN
# 2                   NaT           NaN                NaT           NaN   NaN
# 3                   NaT           NaN                NaT           NaN   NaN
# 4                   NaT           NaN                NaT           NaN   NaN
# ...                 ...           ...                ...           ...   ...
# 1612                NaT           NaN                NaT           NaN   NaN
# 1613                NaT           NaN                NaT           NaN   NaN
# 1614                NaT           NaN                NaT           NaN   NaN
# 1615                NaT           NaN                NaT           NaN   NaN
# 1616                NaT           NaN                NaT           NaN   NaN
#
#      Rejected
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ...       ...
# 1612      NaN
# 1613      NaN
# 1614      NaN
# 1615      NaN
# 1616      NaN
#
# [1617 rows x 16 columns]

# %%
merged_cv_sent_status.head()
# Out:
#    Job ID Owner Company Job Title CV Sent Date       Candidate  \
# 0     110   NaN     NaN       NaN          NaT       Ali Sezer
# 1     110   NaN     NaN       NaN          NaT       Dan Croft
# 2     110   NaN     NaN       NaN          NaT    Mark Ghannam
# 3     110   NaN     NaN       NaN          NaT  Matthias Funke
# 4     110   NaN     NaN       NaN          NaT       Miguel L.
#
#   1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0                NaT           NaN                NaT           NaN
# 1                NaT           NaN                NaT           NaN
# 2                NaT           NaN                NaT           NaN
# 3                NaT           NaN                NaT           NaN
# 4                NaT           NaN                NaT           NaN
#
#   3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                NaT           NaN                NaT           NaN   NaN
# 1                NaT           NaN                NaT           NaN   NaN
# 2                NaT           NaN                NaT           NaN   NaN
# 3                NaT           NaN                NaT           NaN   NaN
# 4                NaT           NaN                NaT           NaN   NaN
#
#   Rejected
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %% [markdown]
# ### Change the status of the candidates

# %%
def determine_status(row):
    # 1. Highest Priority: Is it Rejected?
    if row['Rejected'] == True:
        return 'Rejected'
    
    # 2. Next Priority: Is there an Offer?
    elif row['Offer'] == True:
        return 'Offer'
    
    # 3. Check Interview Stages (Backwards from latest)
    elif row['Interview_4th'] == True:
        return '4th Interview'
    elif row['Interview_3rd'] == True:
        return '3rd Interview'
    elif row['Interview_2nd'] == True:
        return '2nd Interview'
    elif row['Interview_1st'] == True:
        return '1st Interview'
    
    # 4. Default
    else:
        return 'CV Sent'

# Apply it to the DataFrame
merged_cv_sent_status['Status'] = merged_cv_sent_status.apply(determine_status, axis=1)

display(merged_cv_sent_status)
# Out:
#       Job ID              Owner          Company  \
# 0        110                NaN              NaN
# 1        110                NaN              NaN
# 2        110                NaN              NaN
# 3        110                NaN              NaN
# 4        110                NaN              NaN
# ...      ...                ...              ...
# 1612     869       Brad Houston  Native Security
# 1613     870        Max Hogarth  Native Security
# 1614     871      Georgia Price     LaunchDarkly
# 1615     871  Jordan Goodenough     LaunchDarkly
# 1616     873         James Cato       CodeRabbit
#
#                                       Job Title CV Sent Date       Candidate  \
# 0                                           NaN          NaT       Ali Sezer
# 1                                           NaN          NaT       Dan Croft
# 2                                           NaN          NaT    Mark Ghannam
# 3                                           NaN          NaT  Matthias Funke
# 4                                           NaN          NaT       Miguel L.
# ...                                         ...          ...             ...
# 1612     Enterprise Account Executive (Chicago)   2025-12-17   Chris Gardner
# 1613  Enterprise Account Executive (North-East)   2025-12-17      Rich Kroll
# 1614                           Strategic AE U.S   2025-12-19     Dan DiPalma
# 1615                           Strategic AE U.S   2025-12-18   Paul Plofchan
# 1616                        VP Enterprise Sales   2025-12-18    Andrew Sweet
#
#      1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0                   NaT           NaN                NaT           NaN
# 1                   NaT           NaN                NaT           NaN
# 2                   NaT           NaN                NaT           NaN
# 3                   NaT           NaN                NaT           NaN
# 4                   NaT           NaN                NaT           NaN
# ...                 ...           ...                ...           ...
# 1612                NaT           NaN                NaT           NaN
# 1613                NaT           NaN                NaT           NaN
# 1614                NaT           NaN                NaT           NaN
# 1615                NaT           NaN                NaT           NaN
# 1616         2025-12-19          True                NaT           NaN
#
#      3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                   NaT           NaN                NaT           NaN   NaN
# 1                   NaT           NaN                NaT           NaN   NaN
# 2                   NaT           NaN                NaT           NaN   NaN
# 3                   NaT           NaN                NaT           NaN   NaN
# 4                   NaT           NaN                NaT           NaN   NaN
# ...                 ...           ...                ...           ...   ...
# 1612                NaT           NaN                NaT           NaN   NaN
# 1613                NaT           NaN                NaT           NaN   NaN
# 1614                NaT           NaN                NaT           NaN   NaN
# 1615                NaT           NaN                NaT           NaN   NaN
# 1616                NaT           NaN                NaT           NaN   NaN
#
#      Rejected         Status
# 0        True       Rejected
# 1        True       Rejected
# 2        True       Rejected
# 3        True       Rejected
# 4        True       Rejected
# ...       ...            ...
# 1612      NaN        CV Sent
# 1613      NaN        CV Sent
# 1614      NaN        CV Sent
# 1615      NaN        CV Sent
# 1616      NaN  1st Interview
#
# [1617 rows x 17 columns]

# %% [markdown]
# ### Add the column of Action Date - Interview/CV Sent Date

# %%
def get_action_date(row):
    status = row['Status']
    
    # Map status to the corresponding column name
    if status == 'CV Sent':
        return row['CV Sent Date']
    elif status == '1st Interview':
        return row['1st_Interview Date']
    elif status == '2nd Interview':
        return row['2nd_Interview Date']
    elif status == '3rd Interview':
        return row['3rd_Interview Date']
    elif status == '4th Interview':
        return row['4th_Interview Date']
    else:
        return pd.NaT # Return "Not a Time" for unknown statuses

# --- Apply the Function ---
merged_cv_sent_status['Action Date'] = merged_cv_sent_status.apply(get_action_date, axis=1)

# %%
# Drop the N/A rows in the status
merged_cv_sent_status = merged_cv_sent_status[(merged_cv_sent_status.Status != 'N/A') & (merged_cv_sent_status.Status != 'Rejected') & (merged_cv_sent_status.Status != 'Offer')]

merged_cv_sent_status['Status'].value_counts()
# Out:
# Status
# 1st Interview    111
# CV Sent          101
# 2nd Interview     51
# 4th Interview     35
# 3rd Interview     32
# Name: count, dtype: int64

# %%
# Drop the support columns
merged_cv_sent_status = merged_cv_sent_status.drop(columns = ['Interview_1st', 'Interview_2nd', 'Interview_3rd', 'Interview_4th', 'Rejected', 'Offer', 
                                                              '1st_Interview Date', '2nd_Interview Date', '3rd_Interview Date', '4th_Interview Date'])

# %%
display(merged_cv_sent_status)
# Out:
#       Job ID              Owner          Company  \
# 12       196        Ben Clifton         Blockaid
# 19       196        Max Hogarth         Blockaid
# 21       196   Samson Abodunrin         Blockaid
# 23       196        Ben Clifton         Blockaid
# 25       196        Ben Clifton         Blockaid
# ...      ...                ...              ...
# 1612     869       Brad Houston  Native Security
# 1613     870        Max Hogarth  Native Security
# 1614     871      Georgia Price     LaunchDarkly
# 1615     871  Jordan Goodenough     LaunchDarkly
# 1616     873         James Cato       CodeRabbit
#
#                                       Job Title CV Sent Date        Candidate  \
# 12       Enterprise Account Executive (Fintech)   2025-12-16   Connor Yakushi
# 19       Enterprise Account Executive (Fintech)   2025-12-17    Jacob Neuhard
# 21       Enterprise Account Executive (Fintech)   2025-12-05    Jason Fulwood
# 23       Enterprise Account Executive (Fintech)   2025-11-04  Madyson Almeida
# 25       Enterprise Account Executive (Fintech)   2025-11-26       Mike Gomez
# ...                                         ...          ...              ...
# 1612     Enterprise Account Executive (Chicago)   2025-12-17    Chris Gardner
# 1613  Enterprise Account Executive (North-East)   2025-12-17       Rich Kroll
# 1614                           Strategic AE U.S   2025-12-19      Dan DiPalma
# 1615                           Strategic AE U.S   2025-12-18    Paul Plofchan
# 1616                        VP Enterprise Sales   2025-12-18     Andrew Sweet
#
#              Status Action Date
# 12          CV Sent  2025-12-16
# 19          CV Sent  2025-12-17
# 21          CV Sent  2025-12-05
# 23    2nd Interview  2025-12-03
# 25    1st Interview  2025-12-01
# ...             ...         ...
# 1612        CV Sent  2025-12-17
# 1613        CV Sent  2025-12-17
# 1614        CV Sent  2025-12-19
# 1615        CV Sent  2025-12-18
# 1616  1st Interview  2025-12-19
#
# [330 rows x 8 columns]

# %% [markdown]
# ## Export the in-play candidates for the recruiters

# %%
owners_list = merged_cv_sent_status['Owner'].dropna().unique()

merged_cv_sent_status['Action Date'].dt.floor('d')

# Create a folder to keep things organised
output_folder = 'Consultant_Active_Reports'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
for owner in owners_list:
    # 1. Filter for this specific owner
    owner_data = merged_cv_sent_status[merged_cv_sent_status['Owner'] == owner].copy()
    
    # 2. Sort by Job ID (Ascending)
    owner_data = owner_data.sort_values(by='Job ID', ascending=True)
    
    # 3. Select clean columns for the consultant
    export_cols = ['Job ID', 'Company', 'Job Title', 'Candidate', 'Status']
    final_export = owner_data[export_cols]
    
    # 4. Define Filename (Clean the name to avoid file errors)
    clean_owner_name = str(owner).replace(" ", "_").replace("/", "-")
    filename = f"{output_folder}/Active_Candidates_{clean_owner_name}.xlsx"
    
    # 5. Export to csv
    final_export.to_excel(filename, index=False)
    
    print(f"Exported: {filename} ({len(final_export)} candidates)")

print("\n--- ALL EXPORTS COMPLETE ---")
# Out:
# Exported: Consultant_Active_Reports/Active_Candidates_Ben_Clifton.xlsx (24 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Max_Hogarth.xlsx (29 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Samson_Abodunrin.xlsx (28 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Brad_Houston.xlsx (35 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Jordan_Goodenough.xlsx (26 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Joe_Marron.xlsx (24 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ada_Sitnik.xlsx (11 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Weronika_Nazarko.xlsx (14 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Georgia_Price.xlsx (9 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Gabriel_Inema.xlsx (16 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Lilly_Tyler.xlsx (14 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Charlotte_Wells.xlsx (9 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Monie_Rogers.xlsx (10 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Nick_Chaplin.xlsx (12 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Whipp.xlsx (16 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Harry_Thornton.xlsx (4 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Cato.xlsx (12 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Sam_Rudston.xlsx (24 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Connor_Cook.xlsx (5 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Annalisa_Girgenti.xlsx (2 candidates)
#
# --- ALL EXPORTS COMPLETE ---
