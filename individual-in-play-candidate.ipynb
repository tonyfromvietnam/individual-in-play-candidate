# %%
# !pip install plotly

import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import os

# Set a clean, modern default theme for all our plots
pio.templates.default = "plotly_white"

print("Libraries imported successfully.")
# Out:
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (25.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Libraries imported successfully.

# %% [markdown]
# ## Import the Data (CVs Sent, 1st interview, Placements, Rejected)

# %% [markdown]
# ### CVs Sent

# %%
# CV Sent dataset
cv_sents = pd.read_csv('CVs Sent (Last 90 Days).csv')

# First 5 rows
display(cv_sents.head())
# Out:
#    ﻿"Job ID"     Job Owner Created Date         Owner Group   Company  \
# 0        196  Brad Houston   11/09/2025  Brad Houston  EMEA  Blockaid
# 1        196  Brad Houston   17/09/2025   Max Hogarth  EMEA  Blockaid
# 2        196  Brad Houston   24/09/2025   Max Hogarth  EMEA  Blockaid
# 3        196  Brad Houston   02/10/2025   Max Hogarth  EMEA  Blockaid
# 4        196  Brad Houston   05/10/2025  Brad Houston  EMEA  Blockaid
#
#                                 Job Title Job Priority         Candidate  \
# 0  Enterprise Account Executive (Fintech)          NaN      Jack Brigham
# 1  Enterprise Account Executive (Fintech)          NaN      Jared Seavey
# 2  Enterprise Account Executive (Fintech)          NaN         Nik Lulla
# 3  Enterprise Account Executive (Fintech)          NaN  Michael Canfield
# 4  Enterprise Account Executive (Fintech)          NaN     Hassan Makiya
#
#                       Source  Time to Send  CV Sent ID
# 0  LinkedIn Recruiter Inmail           386        4304
# 1                   Bullhorn           392        4401
# 2  LinkedIn Recruiter Inmail           399        4467
# 3                   Bullhorn           407        4590
# 4        LinkedIn Job Advert           410        4609

# %% [markdown]
# ### 1st interviews

# %%
# Interviews dataset
first_interviews = pd.read_csv('1st Interviews (Last 90 Days).csv')

# First 5 rows
display(first_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date             Owner Group      Company  \
# 0      07/09/2025     07/09/2025  Samson Abodunrin  EMEA      Oscilar
# 1      07/09/2025     09/09/2025      Brad Houston  EMEA     Blockaid
# 2      07/09/2025     09/09/2025        Joe Marron  EMEA  Endeavor ai
# 3      08/09/2025     09/09/2025        James Cato    US   CodeRabbit
# 4      08/09/2025     10/09/2025        James Cato    US   CodeRabbit
#
#                                           Job Title Job Priority  \
# 0                                  MidMarket Leader          Hot
# 1            Enterprise Account Executive (Fintech)          NaN
# 2  Founding Enterprise Account Executive (San Fran)          Hot
# 3                                           SE east          Hot
# 4                                           SE east          Hot
#
#       Candidate     Client Contact    Job Type Interview Type  \
# 0  Lauren Lewis                NaN  Contingent  1st Interview
# 1     Tommy Jia      Glenn Rachlin  Contingent  1st Interview
# 2  Andrew Amato  Sahitya Senapathy  Contingent  1st Interview
# 3   VICTOR MOEY                NaN  Contingent  1st Interview
# 4   Sam Dillard                NaN  Contingent  1st Interview
#
#   CRM Interview Type                     Source          Job Owner  Job ID  \
# 0      1st Interview  LinkedIn Recruiter Inmail   Samson Abodunrin     666
# 1      1st Interview  LinkedIn Recruiter Inmail       Brad Houston     196
# 2      1st Interview  LinkedIn Recruiter Inmail  Annalisa Girgenti     678
# 3      1st Interview                   Bullhorn         James Cato     638
# 4      1st Interview  LinkedIn Recruiter Inmail         James Cato     638
#
#    Interview ID
# 0         17183
# 1         17184
# 2         17185
# 3         17220
# 4         17231

# %% [markdown]
# ### 2nd interviews

# %%
# 2nd interviews dataset
second_interviews = pd.read_csv('2nd Interviews (Last 90 Days).csv')

# First 5 rows
display(second_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date         Owner Group         Company  \
# 0      08/09/2025     08/09/2025  Monie Rogers  EMEA           Dash0
# 1      08/09/2025     08/09/2025  Monie Rogers  EMEA           Dash0
# 2      08/09/2025     08/09/2025    Ada Sitnik  EMEA  Octopus Deploy
# 3      08/09/2025     10/09/2025   Sam Rudston  EMEA           Dash0
# 4      08/09/2025     08/09/2025  Monie Rogers  EMEA      CodeRabbit
#
#                                            Job Title Job Priority  \
# 0             Enterprise Account Executive - Benelux          Hot
# 1             Enterprise Account Executive - Benelux          Hot
# 2            Senior Technical Account Manager (EMEA)          Hot
# 3  Enterprise Account Executive - Nordics / Stock...          Hot
# 4                                            AE East          Hot
#
#             Candidate Client Contact    Job Type     Interview Type  \
# 0           Leon Roet            NaN  Contingent  Further Interview
# 1        Sjors Bonjer            NaN  Contingent  Further Interview
# 2  Marc-Steffen Kaesz            NaN  Contingent  Further Interview
# 3         Morten Lund            NaN  Contingent  Further Interview
# 4    Ryan Finkelstein            NaN  Contingent  Further Interview
#
#   CRM Interview Type                     Source          Job Owner  Job ID  \
# 0      2nd Interview  LinkedIn Recruiter Inmail  Annalisa Girgenti     649
# 1      2nd Interview           LinkedIn Message  Annalisa Girgenti     649
# 2      2nd Interview  LinkedIn Recruiter Inmail     Harry Thornton     639
# 3      2nd Interview           LinkedIn Message  Annalisa Girgenti     650
# 4      2nd Interview                   Bullhorn         James Cato     588
#
#    Interview ID
# 0         17193
# 1         17195
# 2         17198
# 3         17202
# 4         17203

# %% [markdown]
# ### 3rd interviews

# %%
# Interviews dataset
third_interviews = pd.read_csv('3rd Interviews (Last 90 Days).csv')

# First 5 rows
display(third_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date         Owner Group     Company  \
# 0      08/09/2025     08/09/2025  Monie Rogers  EMEA       Dash0
# 1      08/09/2025     08/09/2025  Monie Rogers  EMEA       Dash0
# 2      08/09/2025     08/09/2025  Monie Rogers  EMEA  CodeRabbit
# 3      10/09/2025     08/09/2025   Ben Clifton  EMEA   Blink Ops
# 4      11/09/2025     09/09/2025   Ben Clifton  EMEA   Blink Ops
#
#                                 Job Title Job Priority         Candidate  \
# 0  Enterprise Account Executive - Benelux          Hot  Bernard Holleman
# 1  Enterprise Account Executive - Benelux          Hot         Leon Roet
# 2                                 AE East          Hot  Ryan Finkelstein
# 3       Enterprise Account Executive (UK)          Hot  Justin Pemberton
# 4     Enterprise Account Executive (DACH)          Hot     Thomas Escher
#
#     Client Contact    Job Type     Interview Type CRM Interview Type  \
# 0              NaN  Contingent  Further Interview      3rd Interview
# 1              NaN  Contingent  Further Interview      3rd Interview
# 2              NaN  Contingent  Further Interview      3rd Interview
# 3              NaN  Contingent  Further Interview      3rd Interview
# 4  Aaron Beveridge  Contingent  Further Interview      3rd Interview
#
#                       Source          Job Owner  Job ID  Interview ID
# 0           LinkedIn Message  Annalisa Girgenti     649         17191
# 1  LinkedIn Recruiter Inmail  Annalisa Girgenti     649         17194
# 2                   Bullhorn         James Cato     588         17204
# 3                   Bullhorn       Brad Houston     604         17273
# 4                   Bullhorn       Brad Houston     605         17319

# %% [markdown]
# ### 4th interviews

# %%
# Interviews dataset
fourth_interviews = pd.read_csv('4th Interviews (Last 90 Days).csv')

# First 5 rows
display(fourth_interviews.tail())
# Out:
#     ﻿"Created Date" Interview Date              Owner Group      Company  \
# 115      04/12/2025     04/12/2025   Samson Abodunrin  EMEA      Oscilar
# 116      05/12/2025     04/12/2025  Jordan Goodenough  EMEA  Materialize
# 117      05/12/2025     11/12/2025         Joe Marron  EMEA       Laurel
# 118      05/12/2025     04/12/2025        Ben Clifton  EMEA     Novee.io
# 119      05/12/2025     08/12/2025       Monie Rogers  EMEA    PointFive
#
#                                              Job Title Job Priority  \
# 115                                          SE Leader          Hot
# 116  CS3 Materialize - Enterprise Account Executive x3          Hot
# 117                 Enterprise Account Executive UK x4          Hot
# 118                  Enterprise Account Executive (US)          Hot
# 119                                Enterprise AE (EST)          Hot
#
#              Candidate Client Contact         Job Type     Interview Type  \
# 115             Ray Mi            NaN       Contingent  Further Interview
# 116       Tiffany Cole   Nate Stewart  Committed Spend  Further Interview
# 117  Dionys Gragousian    Emil Dyrvig       Contingent  Further Interview
# 118         Rob Harvey     Ido Geffen       Contingent  Further Interview
# 119       Daniel Smith            NaN       Contingent  Further Interview
#
#     CRM Interview Type                     Source  \
# 115      4th Interview  LinkedIn Recruiter Inmail
# 116      4th Interview           LinkedIn Message
# 117      4th Interview  LinkedIn Recruiter Inmail
# 118      4th Interview     Email & Text follow up
# 119      4th Interview           LinkedIn Message
#
#                          Job Owner  Job ID  Interview ID
# 115               Samson Abodunrin     807         20033
# 116  PP Committed Spend Store - UK     751         20039
# 117              Annalisa Girgenti     813         20054
# 118                   Brad Houston     750         20063
# 119                    James Whipp     776         20066

# %% [markdown]
# ### Rejected Candidates

# %%
# Rejects dataset
rejects = pd.read_csv('Rejected Candidates (Last 90 Days).csv')

rejects.rename(columns={'﻿"Job ID"' : 'Job ID'}, inplace=True)

rejects = rejects[['Job ID', 'Job Title', 'Owner', 'Company', 'Candidate']]

# First 5 rows
display(rejects.head())

# Last 5 rows
display(rejects.tail())
# Out:
#    Job ID                                    Job Title              Owner  \
# 0      25               Device Fingerprinting Engineer        James Whipp
# 1      25               Device Fingerprinting Engineer        James Whipp
# 2      73                                        AE UK           Sam Adam
# 3     117                                     CSE EMEA      Emma Connelly
# 4     180  Enterprise Account Executive (NYC Metro P1)  Jordan Goodenough
#
#           Company         Candidate
# 0         Oscilar       Hemant Garg
# 1         Oscilar       Máté Magyar
# 2          Tecton  Stephen Schouten
# 3          Vercel       Erich Simon
# 4  Oasis Security        Matt Tower
#       Job ID                              Job Title         Owner  \
# 1419     815        Enterprise Account Executive UK   Ben Clifton
# 1420     815        Enterprise Account Executive UK    Joe Marron
# 1421     817  Senior Sales Engineer (West/Mountain)  Brad Houston
# 1422     826                            VP of Sales  Brad Houston
# 1423     833                            SDR Manager    Joe Marron
#
#              Company          Candidate
# 1419      Conduct AI      Jamie Summers
# 1420      Conduct AI  Dionys Gragousian
# 1421  Oasis Security   Matthew McKelvey
# 1422  Legit Security      Jim Underwood
# 1423        Blockaid    Branden Bilicki

# %% [markdown]
# ### Offers

# %%
# Offers dataset
offers = pd.read_csv('Offers (Last 90 Days).csv')

# First 5 rows
display(offers.head())

# Last 5 rows
display(offers.tail())
# Out:
#   ﻿"Created Date"           Owner Group        Company  \
# 0      11/09/2025     Ben Clifton  EMEA  Rein Security
# 1      12/09/2025  Harry Thornton  EMEA     Chainguard
# 2      12/09/2025     Ben Clifton  EMEA     Chainguard
# 3      12/09/2025      Joe Marron  EMEA          Dash0
# 4      12/09/2025      Joe Marron  EMEA          Dash0
#
#                                    Job Title Job Priority         Candidate  \
# 0  Enterprise Account Executive (North-East)          Hot   Stephen Collins
# 1       Regional Sales Director (South East)          Hot    Brandon Greene
# 2           Strategic Account Manager (Tola)          Hot       Alex Maruri
# 3                        Dash0 SDR Amsterdam          Hot      Toni Jelovic
# 4                        Dash0 SDR Amsterdam          Hot  Engie Abdelkader
#
#                       Source       Job Owner  Job ID   Offer Outcome
# 0   Cold Call via Signalhire    Brad Houston     630  Offer Extended
# 1                   Bullhorn  Harry Thornton     470  Offer Extended
# 2                   Bullhorn  Harry Thornton     572  Offer Extended
# 3  LinkedIn Recruiter Inmail      Joe Marron     613  Offer Extended
# 4  LinkedIn Recruiter Inmail      Joe Marron     613  Offer Extended
#    ﻿"Created Date"             Owner Group           Company  \
# 63      28/11/2025        Joe Marron  EMEA      LaunchDarkly
# 64      28/11/2025      Brad Houston  EMEA          Blockaid
# 65      30/11/2025      Nick Chaplin  EMEA   Energy Robotics
# 66      01/12/2025  Weronika Nazarko  EMEA  Redwood Software
# 67      03/12/2025       Sam Rudston  EMEA       groundcover
#
#                                  Job Title Job Priority        Candidate  \
# 63  Enterprise Account Executive (Germany)          Hot     Moritz Gross
# 64      CS2 Blockaid - RevOps Manager (NY)         Warm  Kevin Venturino
# 65                             SDR Houston          Hot       Max Wilson
# 66                                   SE UK          Hot  Nicholas Vlatko
# 67                                     SDR          Hot      Tyler Drago
#
#                        Source          Job Owner  Job ID   Offer Outcome
# 63  LinkedIn Recruiter Inmail     Harry Thornton     746  Offer Extended
# 64   Cold Call via Signalhire       Brad Houston     683  Offer Extended
# 65                Sales Robot  Annalisa Girgenti     780  Offer Extended
# 66  LinkedIn Recruiter Inmail         James Cato     673  Offer Extended
# 67   Cold Call via Signalhire         Joe Marron     765  Offer Extended

# %% [markdown]
# ## Re-structure the data, changing their fields

# %%
# Rename the Kpi Date columns to CV Sent Date, change that to datetime type
cv_sents.rename(columns={'Created Date' : 'CV Sent Date', '﻿"Job ID"' : 'Job ID'}, inplace=True)

# Change the CV Sent Date to datetime type
cv_sents['CV Sent Date'] = pd.to_datetime(cv_sents['CV Sent Date'], format='%d/%m/%Y')
cv_sents = cv_sents[['Job ID', 'CV Sent Date', 'Owner', 'Company', 'Job Title', 'Candidate']]

# Display the new dataset
cv_sents.head()
# Out:
#    Job ID CV Sent Date         Owner   Company  \
# 0     196   2025-09-11  Brad Houston  Blockaid
# 1     196   2025-09-17   Max Hogarth  Blockaid
# 2     196   2025-09-24   Max Hogarth  Blockaid
# 3     196   2025-10-02   Max Hogarth  Blockaid
# 4     196   2025-10-05  Brad Houston  Blockaid
#
#                                 Job Title         Candidate
# 0  Enterprise Account Executive (Fintech)      Jack Brigham
# 1  Enterprise Account Executive (Fintech)      Jared Seavey
# 2  Enterprise Account Executive (Fintech)         Nik Lulla
# 3  Enterprise Account Executive (Fintech)  Michael Canfield
# 4  Enterprise Account Executive (Fintech)     Hassan Makiya

# %%
# Rename the Kpi Date columns to Interview Date, change that to datetime type
first_interviews.rename(columns={'Interview Date' : '1st_Interview Date'}, inplace=True)
second_interviews.rename(columns={'Interview Date' : '2nd_Interview Date'}, inplace=True)
third_interviews.rename(columns={'Interview Date' : '3rd_Interview Date'}, inplace=True)
fourth_interviews.rename(columns={'Interview Date' : '4th_Interview Date'}, inplace=True)

# Change the Create Date to datetime type
first_interviews['1st_Interview Date'] = pd.to_datetime(first_interviews['1st_Interview Date'], format='%d/%m/%Y')
first_interviews = first_interviews[['Job ID', 'Job Title', '1st_Interview Date', 'Owner', 'Company', 'Candidate']]

second_interviews['2nd_Interview Date'] = pd.to_datetime(second_interviews['2nd_Interview Date'], format='%d/%m/%Y')
second_interviews = second_interviews[['Job ID', 'Job Title', '2nd_Interview Date', 'Owner', 'Company', 'Candidate']]

third_interviews['3rd_Interview Date'] = pd.to_datetime(third_interviews['3rd_Interview Date'], format='%d/%m/%Y')
third_interviews = third_interviews[['Job ID', 'Job Title', '3rd_Interview Date', 'Owner', 'Company', 'Candidate']]

fourth_interviews['4th_Interview Date'] = pd.to_datetime(fourth_interviews['4th_Interview Date'], format='%d/%m/%Y')
fourth_interviews = fourth_interviews[['Job ID', 'Job Title', '4th_Interview Date', 'Owner', 'Company', 'Candidate']]

# %%
# Rename the Kpi Date columns to Offer Date, change that to datetime type
offers.rename(columns={'﻿"Created Date"' : 'Offer Date'}, inplace=True)

# Change the Create Date to datetime type
offers['Placement Date'] = pd.to_datetime(offers['Offer Date'], format='%d/%m/%Y')

# Change the columns for offers
offers = offers[['Job ID', 'Job Title', 'Owner', 'Company', 'Candidate']]

# Display the new dataset
offers.head()
# Out:
#    Job ID                                  Job Title           Owner  \
# 0     630  Enterprise Account Executive (North-East)     Ben Clifton
# 1     470       Regional Sales Director (South East)  Harry Thornton
# 2     572           Strategic Account Manager (Tola)     Ben Clifton
# 3     613                        Dash0 SDR Amsterdam      Joe Marron
# 4     613                        Dash0 SDR Amsterdam      Joe Marron
#
#          Company         Candidate
# 0  Rein Security   Stephen Collins
# 1     Chainguard    Brandon Greene
# 2     Chainguard       Alex Maruri
# 3          Dash0      Toni Jelovic
# 4          Dash0  Engie Abdelkader

# %% [markdown]
# ## Create a few helper columns to get the status of CVs Sent to Clients

# %%
# Apply helper columns to get the status of CVs
first_interviews['Interview_1st'] = True
second_interviews['Interview_2nd'] = True
third_interviews['Interview_3rd'] = True
fourth_interviews['Interview_4th'] = True
offers['Offer'] = True
rejects['Rejected'] = True

# %%
first_interviews.head()
# Out:
#    Job ID                                         Job Title  \
# 0     666                                  MidMarket Leader
# 1     196            Enterprise Account Executive (Fintech)
# 2     678  Founding Enterprise Account Executive (San Fran)
# 3     638                                           SE east
# 4     638                                           SE east
#
#   1st_Interview Date             Owner      Company     Candidate  \
# 0         2025-09-07  Samson Abodunrin      Oscilar  Lauren Lewis
# 1         2025-09-09      Brad Houston     Blockaid     Tommy Jia
# 2         2025-09-09        Joe Marron  Endeavor ai  Andrew Amato
# 3         2025-09-09        James Cato   CodeRabbit   VICTOR MOEY
# 4         2025-09-10        James Cato   CodeRabbit   Sam Dillard
#
#    Interview_1st
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %% [markdown]
# ### Merge the CV records with the interviews

# %%
# Merge the CV record with the 1st interview record
merged_cv_sent_status = cv_sents.merge(
    first_interviews,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the 2nd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    second_interviews,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the 3rd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    third_interviews,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the 4th interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    fourth_interviews,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the offers record
merged_cv_sent_status = merged_cv_sent_status.merge(
    offers,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the rejected record
merged_cv_sent_status = merged_cv_sent_status.merge(
    rejects,
    on=['Company', 'Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Print the final list
display(merged_cv_sent_status)
# Out:
#       Job ID CV Sent Date         Owner      Company  \
# 0        767   2025-10-29   Max Hogarth    Adaptive6
# 1        767   2025-10-23   Max Hogarth    Adaptive6
# 2        767   2025-10-23   Max Hogarth    Adaptive6
# 3        768   2025-11-05    Ada Sitnik    Adaptive6
# 4        768   2025-10-29    Ada Sitnik    Adaptive6
# ...      ...          ...           ...          ...
# 1873     765   2025-12-03   Sam Rudston  groundcover
# 1874     765   2025-11-20   Sam Rudston  groundcover
# 1875     810   2025-12-03  Monie Rogers  groundcover
# 1876     810   2025-11-13  Monie Rogers  groundcover
# 1877     810   2025-11-21  Nick Chaplin  groundcover
#
#                                               Job Title           Candidate  \
# 0                     Enterprise Account Executive (US)           Dan Greer
# 1                     Enterprise Account Executive (US)         Joe Troiani
# 2                     Enterprise Account Executive (US)       Justin Briody
# 3                            Senior Sales Engineer (US)      Anthony Joanes
# 4                            Senior Sales Engineer (US)  Michael Daganhardt
# ...                                                 ...                 ...
# 1873                                                SDR          Sean Crowe
# 1874                                                SDR         Tyler Drago
# 1875  Mid-Market AE (Observability in NYC, Boston, D...        Justin Beron
# 1876  Mid-Market AE (Observability in NYC, Boston, D...  Nicholas Daileanes
# 1877  Mid-Market AE (Observability in NYC, Boston, D...     Jeffrey Pereira
#
#      1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0            2025-11-12          True                NaT           NaN
# 1            2025-10-27          True                NaT           NaN
# 2            2025-10-29          True                NaT           NaN
# 3                   NaT           NaN                NaT           NaN
# 4            2025-10-30          True                NaT           NaN
# ...                 ...           ...                ...           ...
# 1873                NaT           NaN                NaT           NaN
# 1874         2025-11-25          True         2025-11-28          True
# 1875                NaT           NaN                NaT           NaN
# 1876                NaT           NaN                NaT           NaN
# 1877         2025-11-27          True                NaT           NaN
#
#      3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                   NaT           NaN                NaT           NaN   NaN
# 1                   NaT           NaN                NaT           NaN   NaN
# 2                   NaT           NaN                NaT           NaN   NaN
# 3                   NaT           NaN                NaT           NaN   NaN
# 4                   NaT           NaN                NaT           NaN   NaN
# ...                 ...           ...                ...           ...   ...
# 1873                NaT           NaN                NaT           NaN   NaN
# 1874         2025-12-01          True                NaT           NaN  True
# 1875                NaT           NaN                NaT           NaN   NaN
# 1876                NaT           NaN                NaT           NaN   NaN
# 1877                NaT           NaN                NaT           NaN   NaN
#
#      Rejected
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ...       ...
# 1873      NaN
# 1874      NaN
# 1875      NaN
# 1876     True
# 1877      NaN
#
# [1878 rows x 16 columns]

# %% [markdown]
# ### Change the status of the candidates

# %%
# Create the conditions
conditions = [
    merged_cv_sent_status['Rejected'].notna(),
    merged_cv_sent_status['Interview_4th'].notna() & merged_cv_sent_status ['Rejected'].isna() & merged_cv_sent_status ['Offer'].isna(),
    merged_cv_sent_status['Interview_3rd'].notna() & merged_cv_sent_status ['Rejected'].isna() & merged_cv_sent_status ['Interview_4th'].isna(),
    merged_cv_sent_status['Interview_2nd'].notna() & merged_cv_sent_status ['Rejected'].isna() & merged_cv_sent_status ['Interview_3rd'].isna(),
    merged_cv_sent_status['Interview_1st'].notna() & merged_cv_sent_status ['Rejected'].isna() & merged_cv_sent_status ['Interview_2nd'].isna(),
    merged_cv_sent_status['Rejected'].isna() & merged_cv_sent_status['Interview_1st'].isna() & merged_cv_sent_status ['Offer'].isna()
]

# Create the choices (Interview = Converted, "Rejected = "Non-converted")
choices = [
    "Rejected",
    "4th Interview",
    "3rd Interview",
    "2nd Interview",
    "1st Interview",
    "CV Sent"
]

merged_cv_sent_status["Status"] = np.select(conditions, choices, default="N/A")

display(merged_cv_sent_status)
# Out:
#       Job ID CV Sent Date         Owner      Company  \
# 0        767   2025-10-29   Max Hogarth    Adaptive6
# 1        767   2025-10-23   Max Hogarth    Adaptive6
# 2        767   2025-10-23   Max Hogarth    Adaptive6
# 3        768   2025-11-05    Ada Sitnik    Adaptive6
# 4        768   2025-10-29    Ada Sitnik    Adaptive6
# ...      ...          ...           ...          ...
# 1873     765   2025-12-03   Sam Rudston  groundcover
# 1874     765   2025-11-20   Sam Rudston  groundcover
# 1875     810   2025-12-03  Monie Rogers  groundcover
# 1876     810   2025-11-13  Monie Rogers  groundcover
# 1877     810   2025-11-21  Nick Chaplin  groundcover
#
#                                               Job Title           Candidate  \
# 0                     Enterprise Account Executive (US)           Dan Greer
# 1                     Enterprise Account Executive (US)         Joe Troiani
# 2                     Enterprise Account Executive (US)       Justin Briody
# 3                            Senior Sales Engineer (US)      Anthony Joanes
# 4                            Senior Sales Engineer (US)  Michael Daganhardt
# ...                                                 ...                 ...
# 1873                                                SDR          Sean Crowe
# 1874                                                SDR         Tyler Drago
# 1875  Mid-Market AE (Observability in NYC, Boston, D...        Justin Beron
# 1876  Mid-Market AE (Observability in NYC, Boston, D...  Nicholas Daileanes
# 1877  Mid-Market AE (Observability in NYC, Boston, D...     Jeffrey Pereira
#
#      1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0            2025-11-12          True                NaT           NaN
# 1            2025-10-27          True                NaT           NaN
# 2            2025-10-29          True                NaT           NaN
# 3                   NaT           NaN                NaT           NaN
# 4            2025-10-30          True                NaT           NaN
# ...                 ...           ...                ...           ...
# 1873                NaT           NaN                NaT           NaN
# 1874         2025-11-25          True         2025-11-28          True
# 1875                NaT           NaN                NaT           NaN
# 1876                NaT           NaN                NaT           NaN
# 1877         2025-11-27          True                NaT           NaN
#
#      3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                   NaT           NaN                NaT           NaN   NaN
# 1                   NaT           NaN                NaT           NaN   NaN
# 2                   NaT           NaN                NaT           NaN   NaN
# 3                   NaT           NaN                NaT           NaN   NaN
# 4                   NaT           NaN                NaT           NaN   NaN
# ...                 ...           ...                ...           ...   ...
# 1873                NaT           NaN                NaT           NaN   NaN
# 1874         2025-12-01          True                NaT           NaN  True
# 1875                NaT           NaN                NaT           NaN   NaN
# 1876                NaT           NaN                NaT           NaN   NaN
# 1877                NaT           NaN                NaT           NaN   NaN
#
#      Rejected         Status
# 0        True       Rejected
# 1        True       Rejected
# 2        True       Rejected
# 3        True       Rejected
# 4        True       Rejected
# ...       ...            ...
# 1873      NaN        CV Sent
# 1874      NaN  3rd Interview
# 1875      NaN        CV Sent
# 1876     True       Rejected
# 1877      NaN  1st Interview
#
# [1878 rows x 17 columns]

# %% [markdown]
# ### Add the column of Action Date - Interview/CV Sent Date

# %%
def get_action_date(row):
    status = row['Status']
    
    # Map status to the corresponding column name
    if status == 'CV Sent':
        return row['CV Sent Date']
    elif status == '1st Interview':
        return row['1st_Interview Date']
    elif status == '2nd Interview':
        return row['2nd_Interview Date']
    elif status == '3rd Interview':
        return row['3rd_Interview Date']
    elif status == '4th Interview':
        return row['4th_Interview Date']
    else:
        return pd.NaT # Return "Not a Time" for unknown statuses

# --- Apply the Function ---
merged_cv_sent_status['Action Date'] = merged_cv_sent_status.apply(get_action_date, axis=1)

# %%
# Drop the N/A rows in the status
merged_cv_sent_status = merged_cv_sent_status[(merged_cv_sent_status.Status != 'N/A') & (merged_cv_sent_status.Status != 'Rejected')]

merged_cv_sent_status['Status'].value_counts()
# Out:
# Status
# 1st Interview    136
# CV Sent          106
# 2nd Interview     87
# 3rd Interview     38
# 4th Interview     25
# Name: count, dtype: int64

# %%
# Drop the support columns
merged_cv_sent_status = merged_cv_sent_status.drop(columns = ['Interview_1st', 'Interview_2nd', 'Interview_3rd', 'Interview_4th', 'Rejected', 'Offer', 
                                                              '1st_Interview Date', '2nd_Interview Date', '3rd_Interview Date', '4th_Interview Date'])

# %%
display(merged_cv_sent_status)
# Out:
#       Job ID CV Sent Date             Owner      Company  \
# 10       768   2025-11-25  Weronika Nazarko    Adaptive6
# 12       777   2025-11-13      Brad Houston    Adaptive6
# 13       777   2025-12-05      Brad Houston    Adaptive6
# 15       777   2025-11-27      Brad Houston    Adaptive6
# 16       777   2025-11-05      Brad Houston    Adaptive6
# ...      ...          ...               ...          ...
# 1870     765   2025-12-05       Sam Rudston  groundcover
# 1873     765   2025-12-03       Sam Rudston  groundcover
# 1874     765   2025-11-20       Sam Rudston  groundcover
# 1875     810   2025-12-03      Monie Rogers  groundcover
# 1877     810   2025-11-21      Nick Chaplin  groundcover
#
#                                               Job Title           Candidate  \
# 10                           Senior Sales Engineer (US)      Matthew Hughes
# 12                                          SE Director         Brendan Cox
# 13                                          SE Director  Christopher Hoesly
# 15                                          SE Director       Hermann Hesse
# 16                                          SE Director         Itai Heller
# ...                                                 ...                 ...
# 1870                                                SDR     Robbie Siefring
# 1873                                                SDR          Sean Crowe
# 1874                                                SDR         Tyler Drago
# 1875  Mid-Market AE (Observability in NYC, Boston, D...        Justin Beron
# 1877  Mid-Market AE (Observability in NYC, Boston, D...     Jeffrey Pereira
#
#              Status Action Date
# 10          CV Sent  2025-11-25
# 12    2nd Interview  2025-12-08
# 13          CV Sent  2025-12-05
# 15    1st Interview  2025-12-09
# 16    4th Interview  2025-11-28
# ...             ...         ...
# 1870        CV Sent  2025-12-05
# 1873        CV Sent  2025-12-03
# 1874  3rd Interview  2025-12-01
# 1875        CV Sent  2025-12-03
# 1877  1st Interview  2025-11-27
#
# [392 rows x 8 columns]

# %%
display(merged_cv_sent_status[merged_cv_sent_status['Status'] == '4th Interview'])
# Out:
#       Job ID CV Sent Date              Owner          Company  \
# 16       777   2025-11-05       Brad Houston        Adaptive6
# 85       739   2025-10-15   Samson Abodunrin        Axion Ray
# 115      559          NaT       Brad Houston          Balance
# 202      196          NaT       Brad Houston         Blockaid
# 388      669   2025-10-08       Brad Houston         Blockaid
# 703      702   2025-10-19        James Whipp     Cognition AI
# 706      702   2025-10-24        James Whipp     Cognition AI
# 763      749   2025-11-11        Lilly Tyler        CyCognito
# 766      749   2025-11-13        Lilly Tyler        CyCognito
# 931      785   2025-10-28       Monie Rogers            Dash0
# 1025     808   2025-11-21       Monie Rogers  Energy Robotics
# 1089     813   2025-11-21         Joe Marron           Laurel
# 1160     711   2025-11-05         James Cato             Loop
# 1225     751   2025-11-13  Jordan Goodenough      Materialize
# 1226     751   2025-11-13  Jordan Goodenough      Materialize
# 1256     681   2025-10-29       Monie Rogers         Metaview
# 1322     750   2025-11-05        Ben Clifton         Novee.io
# 1450     731   2025-11-05   Samson Abodunrin          Oscilar
# 1455     807   2025-11-14   Samson Abodunrin          Oscilar
# 1497     661   2025-09-10        James Whipp        PointFive
# 1532     776   2025-11-17       Monie Rogers        PointFive
# 1552     438          NaT       Brad Houston   Prime Security
# 1670     665   2025-10-26   Samson Abodunrin    Safe Security
# 1712     770   2025-11-11        Max Hogarth         TraceBit
# 1713     770   2025-11-11        Max Hogarth         TraceBit
#
#                                               Job Title           Candidate  \
# 16                                          SE Director         Itai Heller
# 85                             BDR Manager (North East)          Matt Henry
# 115                        Enterprise Account Executive        Michael Diaz
# 202              Enterprise Account Executive (Fintech)       Sam Windfield
# 388                                   Head of Marketing         Jeff Meisel
# 703     Forward Deployed Engineer / Sales Engineer (UK)        Ciaran Deasy
# 706     Forward Deployed Engineer / Sales Engineer (UK)       Michel Kiffel
# 763                              Enterprise AE New York        Brett Arpaia
# 766                              Enterprise AE New York  Katie Kupferschmid
# 931                             Commercial AE Amsterdam       Oskar Stepien
# 1025                          Partner Manager (Houston)         Ahmed Mirza
# 1089                 Enterprise Account Executive UK x4   Dionys Gragousian
# 1160  Delivery Transformation Lead (strat implementa...         Noel Thomas
# 1225  CS3 Materialize - Enterprise Account Executive x3        Tiffany Cole
# 1226  CS3 Materialize - Enterprise Account Executive x3         Todd Hixson
# 1256                   Metaview - UK MM / Enterprise AE   Federico  Belluci
# 1322                  Enterprise Account Executive (US)          Rob Harvey
# 1450                                   Enterprise AE x5       Jason Fulwood
# 1455                                          SE Leader              Ray Mi
# 1497                  Channel & Alliances Director - UK        Edward Smart
# 1532                                Enterprise AE (EST)        Daniel Smith
# 1552                                  Head of Marketing       Morgan Grandi
# 1670                                   Enterprise AE UK        Connor Newby
# 1712                              Account Executive NYC        Ben Brighton
# 1713                              Account Executive NYC        Ben Brighton
#
#              Status Action Date
# 16    4th Interview  2025-11-28
# 85    4th Interview  2025-11-19
# 115   4th Interview  2025-09-15
# 202   4th Interview  2025-09-13
# 388   4th Interview  2025-11-18
# 703   4th Interview  2025-12-03
# 706   4th Interview  2025-12-02
# 763   4th Interview  2025-11-28
# 766   4th Interview  2025-12-01
# 931   4th Interview  2025-11-21
# 1025  4th Interview  2025-12-02
# 1089  4th Interview  2025-12-11
# 1160  4th Interview  2026-01-07
# 1225  4th Interview  2025-12-04
# 1226  4th Interview  2025-12-01
# 1256  4th Interview  2025-11-28
# 1322  4th Interview  2025-12-04
# 1450  4th Interview  2025-11-23
# 1455  4th Interview  2025-12-04
# 1497  4th Interview  2025-10-06
# 1532  4th Interview  2025-12-08
# 1552  4th Interview  2025-10-16
# 1670  4th Interview  2025-11-07
# 1712  4th Interview  2025-12-01
# 1713  4th Interview  2025-12-04

# %%
display(merged_cv_sent_status[merged_cv_sent_status['Job ID'] == 707])
# Out:
#      Job ID CV Sent Date             Owner Company  \
# 906     707   2025-11-25  Weronika Nazarko   Dash0
# 909     707   2025-11-27  Weronika Nazarko   Dash0
#
#                                              Job Title         Candidate  \
# 906  Sales Engineer EMEA (UK, Nordics, Benelux, Ger...      Harry Kimpel
# 909  Sales Engineer EMEA (UK, Nordics, Benelux, Ger...  Patrick Schrimpf
#
#             Status Action Date
# 906  2nd Interview  2025-12-15
# 909  2nd Interview  2025-12-05

# %% [markdown]
# ## Export the in-play candidates for the recruiters

# %%
owners_list = merged_cv_sent_status['Owner'].dropna().unique()

merged_cv_sent_status['Action Date'].dt.floor('d')

# Create a folder to keep things organised
output_folder = 'Consultant_Active_Reports'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
for owner in owners_list:
    # 1. Filter for this specific owner
    owner_data = merged_cv_sent_status[merged_cv_sent_status['Owner'] == owner].copy()
    
    # 2. Sort by Job ID (Ascending)
    owner_data = owner_data.sort_values(by='Job ID', ascending=True)
    
    # 3. Select clean columns for the consultant
    export_cols = ['Job ID', 'Company', 'Job Title', 'Candidate', 'Status']
    final_export = owner_data[export_cols]
    
    # 4. Define Filename (Clean the name to avoid file errors)
    clean_owner_name = str(owner).replace(" ", "_").replace("/", "-")
    filename = f"{output_folder}/Active_Candidates_{clean_owner_name}.csv"
    
    # 5. Export to csv
    final_export.to_csv(filename, index=False)
    
    print(f"Exported: {filename} ({len(final_export)} candidates)")

print("\n--- ALL EXPORTS COMPLETE ---")
# Out:
# Exported: Consultant_Active_Reports/Active_Candidates_Weronika_Nazarko.csv (21 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Brad_Houston.csv (36 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Max_Hogarth.csv (22 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ben_Clifton.csv (34 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Jordan_Goodenough.csv (26 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Monie_Rogers.csv (23 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Samson_Abodunrin.csv (39 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Joe_Marron.csv (35 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Renee-Sarah_Lewis.csv (4 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ada_Sitnik.csv (18 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Connor_Cook.csv (4 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Harry_Thornton.csv (8 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Cato.csv (28 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Nick_Chaplin.csv (13 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Whipp.csv (18 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Charlotte_Wells.csv (7 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Lilly_Tyler.csv (12 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Sam_Rudston.csv (21 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Georgia_Price.csv (5 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Annalisa_Girgenti.csv (10 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Gabriel_Inema.csv (8 candidates)
#
# --- ALL EXPORTS COMPLETE ---
