# %%
# !pip install plotly

import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import os

# Set a clean, modern default theme for all our plots
pio.templates.default = "plotly_white"

print("Libraries imported successfully.")
# Out:
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (25.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Libraries imported successfully.

# %% [markdown]
# ## Import the Data (CVs Sent, 1st interview, Placements, Rejected)

# %% [markdown]
# ### CVs Sent

# %%
# CV Sent dataset
cv_sents = pd.read_csv('CVs Sent (Last 90 Days).csv')

# First 5 rows
display(cv_sents.head())
# Out:
#    ﻿"Job ID"     Job Owner Created Date         Owner Group   Company  \
# 0        196  Brad Houston   17/09/2025   Max Hogarth  EMEA  Blockaid
# 1        196  Brad Houston   24/09/2025   Max Hogarth  EMEA  Blockaid
# 2        196  Brad Houston   02/10/2025   Max Hogarth  EMEA  Blockaid
# 3        196  Brad Houston   05/10/2025  Brad Houston  EMEA  Blockaid
# 4        196  Brad Houston   09/10/2025   Max Hogarth  EMEA  Blockaid
#
#                                 Job Title Job Priority         Candidate  \
# 0  Enterprise Account Executive (Fintech)          NaN      Jared Seavey
# 1  Enterprise Account Executive (Fintech)          NaN         Nik Lulla
# 2  Enterprise Account Executive (Fintech)          NaN  Michael Canfield
# 3  Enterprise Account Executive (Fintech)          NaN     Hassan Makiya
# 4  Enterprise Account Executive (Fintech)          NaN     DEREK ORGERON
#
#                       Source  Time to Send  CV Sent ID
# 0                   Bullhorn           392        4401
# 1  LinkedIn Recruiter Inmail           399        4467
# 2                   Bullhorn           407        4590
# 3        LinkedIn Job Advert           410        4609
# 4  LinkedIn Recruiter Inmail           414        4667

# %% [markdown]
# ### 1st interviews

# %%
# Interviews dataset
first_interviews = pd.read_csv('1st Interviews (Last 90 Days).csv')

# First 5 rows
display(first_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date              Owner Group    Company  \
# 0      12/09/2025     12/09/2025   Samson Abodunrin  EMEA    Oscilar
# 1      12/09/2025     12/09/2025   Samson Abodunrin  EMEA    Oscilar
# 2      12/09/2025     12/09/2025         Ada Sitnik  EMEA  PointFive
# 3      12/09/2025     12/09/2025       Brad Houston  EMEA    Factory
# 4      12/09/2025     17/09/2025  Jordan Goodenough  EMEA  UnifyApps
#
#                            Job Title Job Priority         Candidate  \
# 0  Director of Enterprise Sales (US)          Hot  Michael Atkinson
# 1                   MidMarket Leader          Hot    Brian Malajian
# 2                            SDR EST          NaN    Charlie Denker
# 3        CS1 Factory - Enterprise AE          Hot      Jose Palafox
# 4    UnifyApps - Solutions Architect          Hot         Wei Jiang
#
#      Client Contact         Job Type Interview Type CRM Interview Type  \
# 0               NaN       Contingent  1st Interview      1st Interview
# 1               NaN       Contingent  1st Interview      1st Interview
# 2  Randy Bartlewski       Contingent  1st Interview      1st Interview
# 3    Matan Grinberg  Committed Spend  1st Interview      1st Interview
# 4    Colin Callahan       Contingent  1st Interview      1st Interview
#
#                       Source          Job Owner  Job ID  Interview ID
# 0  LinkedIn Recruiter Inmail     Harry Thornton     556         17353
# 1  LinkedIn Recruiter Inmail   Samson Abodunrin     666         17354
# 2  LinkedIn Recruiter Inmail        James Whipp     584         17364
# 3   Cold Call via Signalhire  Annalisa Girgenti     633         17372
# 4  LinkedIn Recruiter Inmail  Jordan Goodenough     668         17377

# %% [markdown]
# ### 2nd interviews

# %%
# 2nd interviews dataset
second_interviews = pd.read_csv('2nd Interviews (Last 90 Days).csv')

# First 5 rows
display(second_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date         Owner Group          Company  \
# 0      12/09/2025     12/09/2025  Monie Rogers  EMEA            Dash0
# 1      12/09/2025     18/09/2025   Ben Clifton  EMEA        Blink Ops
# 2      12/09/2025     11/09/2025   Ben Clifton  EMEA        UnifyApps
# 3      12/09/2025     12/09/2025    Ada Sitnik  EMEA  Legion Security
# 4      12/09/2025     12/09/2025   Ben Clifton  EMEA       Chainguard
#
#                            Job Title Job Priority        Candidate  \
# 0            Commercial AE Amsterdam          Hot      Oskar Munch
# 1  Enterprise Account Executive (UK)          Hot  Chris Ogrizovic
# 2       UnifyApps - US Enterprise AE          Hot      Scott Ellis
# 3                Sales Engineer (US)          NaN     Walter  Abel
# 4   Strategic Account Manager (Tola)          Hot      Brandi Goss
#
#   Client Contact         Job Type     Interview Type CRM Interview Type  \
# 0            NaN       Contingent  Further Interview      2nd Interview
# 1            NaN       Contingent  Further Interview      2nd Interview
# 2            NaN       Contingent  Further Interview      2nd Interview
# 3            NaN  Committed Spend  Further Interview      2nd Interview
# 4            NaN       Contingent  Further Interview      2nd Interview
#
#                    Source          Job Owner  Job ID  Interview ID
# 0        LinkedIn Message         Joe Marron     622         17348
# 1                Bullhorn       Brad Houston     604         17356
# 2                Bullhorn  Jordan Goodenough     656         17355
# 3  Email & Text follow up        James Whipp     580         17357
# 4                Bullhorn     Harry Thornton     572         17358

# %% [markdown]
# ### 3rd interviews

# %%
# Interviews dataset
third_interviews = pd.read_csv('3rd Interviews (Last 90 Days).csv')

# First 5 rows
display(third_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date         Owner Group          Company  \
# 0      12/09/2025     12/09/2025  Monie Rogers  EMEA            Navan
# 1      12/09/2025     12/09/2025  Monie Rogers  EMEA            Dash0
# 2      12/09/2025     12/09/2025    Ada Sitnik  EMEA  Legion Security
# 3      12/09/2025     15/09/2025   Sam Rudston  EMEA            Dash0
# 4      12/09/2025     12/09/2025   Ben Clifton  EMEA         Doxel.ai
#
#                                            Job Title Job Priority  \
# 0                               Mid-Market AE Austin          Hot
# 1                                  Commercial AE NYC          Hot
# 2                                Sales Engineer (US)          NaN
# 3  Enterprise Account Executive - Nordics / Stock...          Hot
# 4   CS1 Doxel - Regional Sales Director (CST or EST)          Hot
#
#            Candidate Client Contact         Job Type     Interview Type  \
# 0       Dillon Marrs            NaN       Contingent  Further Interview
# 1       Bruna Corbin            NaN       Contingent  Further Interview
# 2     Mitchell Krane            NaN  Committed Spend  Further Interview
# 3        Morten Lund            NaN       Contingent  Further Interview
# 4  Alexander Laursen            NaN  Committed Spend  Further Interview
#
#   CRM Interview Type                     Source          Job Owner  Job ID  \
# 0      3rd Interview           LinkedIn Message         James Cato     659
# 1      3rd Interview           LinkedIn Message         Joe Marron     617
# 2      3rd Interview  LinkedIn Recruiter Inmail        James Whipp     580
# 3      3rd Interview           LinkedIn Message  Annalisa Girgenti     650
# 4      3rd Interview                   Bullhorn         Joe Marron     567
#
#    Interview ID
# 0         17345
# 1         17347
# 2         17350
# 3         17349
# 4         17352

# %% [markdown]
# ### 4th interviews

# %%
# Interviews dataset
fourth_interviews = pd.read_csv('4th Interviews (Last 90 Days).csv')

# First 5 rows
display(fourth_interviews.tail())
# Out:
#     ﻿"Created Date" Interview Date             Owner Group          Company  \
# 119      07/12/2025     08/12/2025       Sam Rudston  EMEA           Laurel
# 120      08/12/2025     08/12/2025      Brad Houston  EMEA           Allium
# 121      08/12/2025     03/12/2025       Ben Clifton  EMEA  Energy Robotics
# 122      08/12/2025     08/12/2025       James Whipp  EMEA        PointFive
# 123      09/12/2025     11/12/2025  Weronika Nazarko  EMEA             Mabl
#
#               Job Title Job Priority           Candidate     Client Contact  \
# 119        BDR New York          Hot     Junaid Farooqui                NaN
# 120  Solutions Engineer          Hot       Silja Petasch       Aaron Geller
# 121          SDR London          Hot        Morgan Males                NaN
# 122             VP EMEA          Hot  Patrick Wittenberg                NaN
# 123     Partner Manager          Hot        Alix Moreira  Anthony Palladino
#
#        Job Type     Interview Type CRM Interview Type  \
# 119  Contingent  Further Interview      4th Interview
# 120  Contingent  Further Interview      4th Interview
# 121  Contingent  Further Interview      4th Interview
# 122  Contingent  Further Interview      4th Interview
# 123  Contingent  Further Interview      4th Interview
#
#                         Source          Job Owner  Job ID  Interview ID
# 119  LinkedIn Recruiter Inmail      Gabriel Inema     828         20118
# 120  LinkedIn Recruiter Inmail       Brad Houston     787         20123
# 121        LinkedIn Job Advert  Annalisa Girgenti     779         20128
# 122  LinkedIn Recruiter Inmail        James Whipp     677         20147
# 123  LinkedIn Recruiter Inmail         James Cato     788         20164

# %% [markdown]
# ### Rejected Candidates

# %%
# Rejects dataset
rejects = pd.read_csv('Rejected Candidates (Last 90 Days).csv')

rejects.rename(columns={'﻿"Job ID"' : 'Job ID'}, inplace=True)

rejects = rejects[['Job ID', 'Candidate']]

# First 5 rows
display(rejects.head())
# Out:
#    Job ID       Candidate
# 0      25     Hemant Garg
# 1      25     Máté Magyar
# 2     110    Mark Ghannam
# 3     110  Matthias Funke
# 4     110       Dan Croft

# %% [markdown]
# ### Offers

# %%
# Offers dataset
offers = pd.read_csv('Offers (Last 90 Days).csv')

offers = offers[['Job ID', 'Candidate']]

# Last 5 rows
display(offers.tail())
# Out:
#     Job ID              Candidate
# 67     681      Federico  Belluci
# 68     779           Morgan Males
# 69     803  Nikolaos Papadopoulos
# 70     828        Junaid Farooqui
# 71     656       Ryan Finkelstein

# %% [markdown]
# ## Re-structure the data, changing their fields

# %%
# Rename the Kpi Date columns to CV Sent Date, change that to datetime type
cv_sents.rename(columns={'Created Date' : 'CV Sent Date', '﻿"Job ID"' : 'Job ID'}, inplace=True)

# Change the CV Sent Date to datetime type
cv_sents['CV Sent Date'] = pd.to_datetime(cv_sents['CV Sent Date'], format='%d/%m/%Y')
cv_sents = cv_sents[['Job ID', 'Owner', 'Company', 'Job Title', 'CV Sent Date', 'Candidate']]

# Display the new dataset
cv_sents.head()
# Out:
#    Job ID         Owner   Company                               Job Title  \
# 0     196   Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 1     196   Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 2     196   Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
# 3     196  Brad Houston  Blockaid  Enterprise Account Executive (Fintech)
# 4     196   Max Hogarth  Blockaid  Enterprise Account Executive (Fintech)
#
#   CV Sent Date         Candidate
# 0   2025-09-17      Jared Seavey
# 1   2025-09-24         Nik Lulla
# 2   2025-10-02  Michael Canfield
# 3   2025-10-05     Hassan Makiya
# 4   2025-10-09     DEREK ORGERON

# %%
# Rename the Kpi Date columns to Interview Date, change that to datetime type
first_interviews.rename(columns={'Interview Date' : '1st_Interview Date'}, inplace=True)
second_interviews.rename(columns={'Interview Date' : '2nd_Interview Date'}, inplace=True)
third_interviews.rename(columns={'Interview Date' : '3rd_Interview Date'}, inplace=True)
fourth_interviews.rename(columns={'Interview Date' : '4th_Interview Date'}, inplace=True)

# Change the Create Date to datetime type
first_interviews['1st_Interview Date'] = pd.to_datetime(first_interviews['1st_Interview Date'], format='%d/%m/%Y')
first_interviews = first_interviews[['Job ID', '1st_Interview Date', 'Candidate']]

second_interviews['2nd_Interview Date'] = pd.to_datetime(second_interviews['2nd_Interview Date'], format='%d/%m/%Y')
second_interviews = second_interviews[['Job ID', '2nd_Interview Date', 'Candidate']]

third_interviews['3rd_Interview Date'] = pd.to_datetime(third_interviews['3rd_Interview Date'], format='%d/%m/%Y')
third_interviews = third_interviews[['Job ID', '3rd_Interview Date', 'Candidate']]

fourth_interviews['4th_Interview Date'] = pd.to_datetime(fourth_interviews['4th_Interview Date'], format='%d/%m/%Y')
fourth_interviews = fourth_interviews[['Job ID', '4th_Interview Date','Candidate']]

# %% [markdown]
# ## Create a few helper columns to get the status of CVs Sent to Clients

# %%
# Apply helper columns to get the status of CVs
first_interviews['Interview_1st'] = True
second_interviews['Interview_2nd'] = True
third_interviews['Interview_3rd'] = True
fourth_interviews['Interview_4th'] = True
offers['Offer'] = True
rejects['Rejected'] = True

# %%
first_interviews.head()
# Out:
#    Job ID 1st_Interview Date         Candidate  Interview_1st
# 0     556         2025-09-12  Michael Atkinson           True
# 1     666         2025-09-12    Brian Malajian           True
# 2     584         2025-09-12    Charlie Denker           True
# 3     633         2025-09-12      Jose Palafox           True
# 4     668         2025-09-17         Wei Jiang           True

# %% [markdown]
# ### Merge the CV records with the interviews

# %%
# Merge the CV record with the 1st interview record
merged_cv_sent_status = cv_sents.merge(
    first_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 2nd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    second_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 3rd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    third_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the 4th interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    fourth_interviews,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the offers record
merged_cv_sent_status = merged_cv_sent_status.merge(
    offers,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Merge the CV record with the rejected record
merged_cv_sent_status = merged_cv_sent_status.merge(
    rejects,
    on=['Job ID', 'Candidate'],
    how='outer'
)

# Print the final list
display(merged_cv_sent_status)
# Out:
#       Job ID              Owner       Company  \
# 0         25                NaN           NaN
# 1         25                NaN           NaN
# 2        110                NaN           NaN
# 3        110                NaN           NaN
# 4        110                NaN           NaN
# ...      ...                ...           ...
# 1797     843        Max Hogarth    Red Access
# 1798     846       Monie Rogers         Dash0
# 1799     847         Joe Marron     Simile.ai
# 1800     847  Jordan Goodenough     Simile.ai
# 1801     851      Georgia Price  Cognition AI
#
#                               Job Title CV Sent Date       Candidate  \
# 0                                   NaN          NaT     Hemant Garg
# 1                                   NaN          NaT     Máté Magyar
# 2                                   NaN          NaT       Ali Sezer
# 3                                   NaN          NaT       Dan Croft
# 4                                   NaN          NaT    Mark Ghannam
# ...                                 ...          ...             ...
# 1797    Enterprise Account Executive UK   2025-12-10  Michele Maioli
# 1798      Dash0 Commercial AE NY/Boston   2025-12-05    Justin Beron
# 1799   CS1 Simile.ai - Enterprise AE x2   2025-12-09     Danny Wymer
# 1800   CS1 Simile.ai - Enterprise AE x2   2025-12-09   Sanat Valecha
# 1801  Cognition MM AE (NYC, SF, Austin)   2025-12-09   Connor  Riley
#
#      1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0                   NaT           NaN                NaT           NaN
# 1                   NaT           NaN                NaT           NaN
# 2                   NaT           NaN                NaT           NaN
# 3                   NaT           NaN                NaT           NaN
# 4                   NaT           NaN                NaT           NaN
# ...                 ...           ...                ...           ...
# 1797                NaT           NaN                NaT           NaN
# 1798                NaT           NaN                NaT           NaN
# 1799         2025-12-16          True                NaT           NaN
# 1800                NaT           NaN                NaT           NaN
# 1801                NaT           NaN                NaT           NaN
#
#      3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                   NaT           NaN                NaT           NaN   NaN
# 1                   NaT           NaN                NaT           NaN   NaN
# 2                   NaT           NaN                NaT           NaN   NaN
# 3                   NaT           NaN                NaT           NaN   NaN
# 4                   NaT           NaN                NaT           NaN   NaN
# ...                 ...           ...                ...           ...   ...
# 1797                NaT           NaN                NaT           NaN   NaN
# 1798                NaT           NaN                NaT           NaN   NaN
# 1799                NaT           NaN                NaT           NaN   NaN
# 1800                NaT           NaN                NaT           NaN   NaN
# 1801                NaT           NaN                NaT           NaN   NaN
#
#      Rejected
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ...       ...
# 1797      NaN
# 1798      NaN
# 1799      NaN
# 1800      NaN
# 1801      NaN
#
# [1802 rows x 16 columns]

# %%
merged_cv_sent_status.head()
# Out:
#    Job ID Owner Company Job Title CV Sent Date     Candidate  \
# 0      25   NaN     NaN       NaN          NaT   Hemant Garg
# 1      25   NaN     NaN       NaN          NaT   Máté Magyar
# 2     110   NaN     NaN       NaN          NaT     Ali Sezer
# 3     110   NaN     NaN       NaN          NaT     Dan Croft
# 4     110   NaN     NaN       NaN          NaT  Mark Ghannam
#
#   1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0                NaT           NaN                NaT           NaN
# 1                NaT           NaN                NaT           NaN
# 2                NaT           NaN                NaT           NaN
# 3                NaT           NaN                NaT           NaN
# 4                NaT           NaN                NaT           NaN
#
#   3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                NaT           NaN                NaT           NaN   NaN
# 1                NaT           NaN                NaT           NaN   NaN
# 2                NaT           NaN                NaT           NaN   NaN
# 3                NaT           NaN                NaT           NaN   NaN
# 4                NaT           NaN                NaT           NaN   NaN
#
#   Rejected
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True

# %% [markdown]
# ### Change the status of the candidates

# %%
def determine_status(row):
    # 1. Highest Priority: Is it Rejected?
    if row['Rejected'] == True:
        return 'Rejected'
    
    # 2. Next Priority: Is there an Offer?
    elif row['Offer'] == True:
        return 'Offer'
    
    # 3. Check Interview Stages (Backwards from latest)
    elif row['Interview_4th'] == True:
        return '4th Interview'
    elif row['Interview_3rd'] == True:
        return '3rd Interview'
    elif row['Interview_2nd'] == True:
        return '2nd Interview'
    elif row['Interview_1st'] == True:
        return '1st Interview'
    
    # 4. Default
    else:
        return 'CV Sent'

# Apply it to the DataFrame
merged_cv_sent_status['Status'] = merged_cv_sent_status.apply(determine_status, axis=1)

display(merged_cv_sent_status)
# Out:
#       Job ID              Owner       Company  \
# 0         25                NaN           NaN
# 1         25                NaN           NaN
# 2        110                NaN           NaN
# 3        110                NaN           NaN
# 4        110                NaN           NaN
# ...      ...                ...           ...
# 1797     843        Max Hogarth    Red Access
# 1798     846       Monie Rogers         Dash0
# 1799     847         Joe Marron     Simile.ai
# 1800     847  Jordan Goodenough     Simile.ai
# 1801     851      Georgia Price  Cognition AI
#
#                               Job Title CV Sent Date       Candidate  \
# 0                                   NaN          NaT     Hemant Garg
# 1                                   NaN          NaT     Máté Magyar
# 2                                   NaN          NaT       Ali Sezer
# 3                                   NaN          NaT       Dan Croft
# 4                                   NaN          NaT    Mark Ghannam
# ...                                 ...          ...             ...
# 1797    Enterprise Account Executive UK   2025-12-10  Michele Maioli
# 1798      Dash0 Commercial AE NY/Boston   2025-12-05    Justin Beron
# 1799   CS1 Simile.ai - Enterprise AE x2   2025-12-09     Danny Wymer
# 1800   CS1 Simile.ai - Enterprise AE x2   2025-12-09   Sanat Valecha
# 1801  Cognition MM AE (NYC, SF, Austin)   2025-12-09   Connor  Riley
#
#      1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0                   NaT           NaN                NaT           NaN
# 1                   NaT           NaN                NaT           NaN
# 2                   NaT           NaN                NaT           NaN
# 3                   NaT           NaN                NaT           NaN
# 4                   NaT           NaN                NaT           NaN
# ...                 ...           ...                ...           ...
# 1797                NaT           NaN                NaT           NaN
# 1798                NaT           NaN                NaT           NaN
# 1799         2025-12-16          True                NaT           NaN
# 1800                NaT           NaN                NaT           NaN
# 1801                NaT           NaN                NaT           NaN
#
#      3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                   NaT           NaN                NaT           NaN   NaN
# 1                   NaT           NaN                NaT           NaN   NaN
# 2                   NaT           NaN                NaT           NaN   NaN
# 3                   NaT           NaN                NaT           NaN   NaN
# 4                   NaT           NaN                NaT           NaN   NaN
# ...                 ...           ...                ...           ...   ...
# 1797                NaT           NaN                NaT           NaN   NaN
# 1798                NaT           NaN                NaT           NaN   NaN
# 1799                NaT           NaN                NaT           NaN   NaN
# 1800                NaT           NaN                NaT           NaN   NaN
# 1801                NaT           NaN                NaT           NaN   NaN
#
#      Rejected         Status
# 0        True       Rejected
# 1        True       Rejected
# 2        True       Rejected
# 3        True       Rejected
# 4        True       Rejected
# ...       ...            ...
# 1797      NaN        CV Sent
# 1798      NaN        CV Sent
# 1799      NaN  1st Interview
# 1800      NaN        CV Sent
# 1801      NaN        CV Sent
#
# [1802 rows x 17 columns]

# %% [markdown]
# ### Add the column of Action Date - Interview/CV Sent Date

# %%
def get_action_date(row):
    status = row['Status']
    
    # Map status to the corresponding column name
    if status == 'CV Sent':
        return row['CV Sent Date']
    elif status == '1st Interview':
        return row['1st_Interview Date']
    elif status == '2nd Interview':
        return row['2nd_Interview Date']
    elif status == '3rd Interview':
        return row['3rd_Interview Date']
    elif status == '4th Interview':
        return row['4th_Interview Date']
    else:
        return pd.NaT # Return "Not a Time" for unknown statuses

# --- Apply the Function ---
merged_cv_sent_status['Action Date'] = merged_cv_sent_status.apply(get_action_date, axis=1)

# %%
# Drop the N/A rows in the status
merged_cv_sent_status = merged_cv_sent_status[(merged_cv_sent_status.Status != 'N/A') & (merged_cv_sent_status.Status != 'Rejected') & (merged_cv_sent_status.Status != 'Offer')]

merged_cv_sent_status['Status'].value_counts()
# Out:
# Status
# 1st Interview    125
# CV Sent           89
# 2nd Interview     71
# 3rd Interview     32
# 4th Interview     21
# Name: count, dtype: int64

# %%
# Drop the support columns
merged_cv_sent_status = merged_cv_sent_status.drop(columns = ['Interview_1st', 'Interview_2nd', 'Interview_3rd', 'Interview_4th', 'Rejected', 'Offer', 
                                                              '1st_Interview Date', '2nd_Interview Date', '3rd_Interview Date', '4th_Interview Date'])

# %%
display(merged_cv_sent_status)
# Out:
#       Job ID              Owner       Company  \
# 13       196        Ben Clifton      Blockaid
# 14       196       Brad Houston      Blockaid
# 19       196        Ben Clifton      Blockaid
# 23       196   Samson Abodunrin      Blockaid
# 25       196        Ben Clifton      Blockaid
# ...      ...                ...           ...
# 1797     843        Max Hogarth    Red Access
# 1798     846       Monie Rogers         Dash0
# 1799     847         Joe Marron     Simile.ai
# 1800     847  Jordan Goodenough     Simile.ai
# 1801     851      Georgia Price  Cognition AI
#
#                                    Job Title CV Sent Date          Candidate  \
# 13    Enterprise Account Executive (Fintech)   2025-12-03       Brandon Hood
# 14    Enterprise Account Executive (Fintech)   2025-11-19  Brendan McMenimen
# 19    Enterprise Account Executive (Fintech)   2025-11-26       Erik Gallant
# 23    Enterprise Account Executive (Fintech)   2025-12-05      Jason Fulwood
# 25    Enterprise Account Executive (Fintech)   2025-11-04    Madyson Almeida
# ...                                      ...          ...                ...
# 1797         Enterprise Account Executive UK   2025-12-10     Michele Maioli
# 1798           Dash0 Commercial AE NY/Boston   2025-12-05       Justin Beron
# 1799        CS1 Simile.ai - Enterprise AE x2   2025-12-09        Danny Wymer
# 1800        CS1 Simile.ai - Enterprise AE x2   2025-12-09      Sanat Valecha
# 1801       Cognition MM AE (NYC, SF, Austin)   2025-12-09      Connor  Riley
#
#              Status Action Date
# 13          CV Sent  2025-12-03
# 14    3rd Interview  2025-12-08
# 19    1st Interview  2025-12-02
# 23          CV Sent  2025-12-05
# 25    2nd Interview  2025-12-03
# ...             ...         ...
# 1797        CV Sent  2025-12-10
# 1798        CV Sent  2025-12-05
# 1799  1st Interview  2025-12-16
# 1800        CV Sent  2025-12-09
# 1801        CV Sent  2025-12-09
#
# [338 rows x 8 columns]

# %% [markdown]
# ## Export the in-play candidates for the recruiters

# %%
owners_list = merged_cv_sent_status['Owner'].dropna().unique()

merged_cv_sent_status['Action Date'].dt.floor('d')

# Create a folder to keep things organised
output_folder = 'Consultant_Active_Reports'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
for owner in owners_list:
    # 1. Filter for this specific owner
    owner_data = merged_cv_sent_status[merged_cv_sent_status['Owner'] == owner].copy()
    
    # 2. Sort by Job ID (Ascending)
    owner_data = owner_data.sort_values(by='Job ID', ascending=True)
    
    # 3. Select clean columns for the consultant
    export_cols = ['Job ID', 'Company', 'Job Title', 'Candidate', 'Status']
    final_export = owner_data[export_cols]
    
    # 4. Define Filename (Clean the name to avoid file errors)
    clean_owner_name = str(owner).replace(" ", "_").replace("/", "-")
    filename = f"{output_folder}/Active_Candidates_{clean_owner_name}.csv"
    
    # 5. Export to csv
    final_export.to_csv(filename, index=False)
    
    print(f"Exported: {filename} ({len(final_export)} candidates)")

print("\n--- ALL EXPORTS COMPLETE ---")
# Out:
# Exported: Consultant_Active_Reports/Active_Candidates_Ben_Clifton.csv (31 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Brad_Houston.csv (30 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Samson_Abodunrin.csv (25 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Max_Hogarth.csv (26 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Jordan_Goodenough.csv (26 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Joe_Marron.csv (27 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Renee-Sarah_Lewis.csv (3 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ada_Sitnik.csv (15 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Weronika_Nazarko.csv (19 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Annalisa_Girgenti.csv (6 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Lilly_Tyler.csv (10 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Monie_Rogers.csv (16 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Gabriel_Inema.csv (9 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Nick_Chaplin.csv (11 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Sam_Rudston.csv (17 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Whipp.csv (12 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Harry_Thornton.csv (8 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Cato.csv (23 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Charlotte_Wells.csv (5 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Georgia_Price.csv (7 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Connor_Cook.csv (3 candidates)
#
# --- ALL EXPORTS COMPLETE ---
