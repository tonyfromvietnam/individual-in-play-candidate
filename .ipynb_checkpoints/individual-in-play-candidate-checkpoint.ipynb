# %%
# !pip install plotly

import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
import os

# Set a clean, modern default theme for all our plots
pio.templates.default = "plotly_white"

print("Libraries imported successfully.")
# Out:
# Requirement already satisfied: plotly in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from plotly) (25.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Libraries imported successfully.

# %% [markdown]
# ## Import the Data (CVs Sent, 1st interview, Placements, Rejected)

# %% [markdown]
# ### CVs Sent

# %%
# CV Sent dataset
cv_sents = pd.read_csv('CVs Sent (Last 30 Days).csv')

# First 5 rows
display(cv_sents.head())
# Out:
#    ﻿"Job ID"     Job Owner Created Date         Owner Group   Company  \
# 0        196  Brad Houston   04/11/2025   Sam Rudston  EMEA  Blockaid
# 1        196  Brad Houston   04/11/2025   Ben Clifton  EMEA  Blockaid
# 2        196  Brad Houston   10/11/2025   Ben Clifton  EMEA  Blockaid
# 3        196  Brad Houston   19/11/2025  Brad Houston  EMEA  Blockaid
# 4        196  Brad Houston   26/11/2025   Ben Clifton  EMEA  Blockaid
#
#                                 Job Title Job Priority          Candidate  \
# 0  Enterprise Account Executive (Fintech)          NaN  Darrell Van Dyken
# 1  Enterprise Account Executive (Fintech)          NaN    Madyson Almeida
# 2  Enterprise Account Executive (Fintech)          NaN      Dennis Coombs
# 3  Enterprise Account Executive (Fintech)          NaN  Brendan McMenimen
# 4  Enterprise Account Executive (Fintech)          NaN         Mike Gomez
#
#                       Source  Time to Send  CV Sent ID
# 0           LinkedIn Message           440        4994
# 1     Email & Text follow up           440        5009
# 2  LinkedIn Recruiter Inmail           446        5106
# 3  LinkedIn Recruiter Inmail           455        5230
# 4   Cold Call via Signalhire           462        5342

# %% [markdown]
# ### 1st interviews

# %%
# Interviews dataset
first_interviews = pd.read_csv('1st Interviews (Last 30 Days).csv')

# First 5 rows
display(first_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date              Owner Group       Company  \
# 0      02/11/2025     02/11/2025        Ben Clifton  EMEA  Cognition AI
# 1      02/11/2025     11/11/2025  Jordan Goodenough  EMEA  Cognition AI
# 2      02/11/2025     04/11/2025         Joe Marron  EMEA     Axion Ray
# 3      02/11/2025     02/11/2025   Samson Abodunrin  EMEA    Antithesis
# 4      03/11/2025     03/11/2025         James Cato    US           Rox
#
#                                            Job Title Job Priority  \
# 0                  Enterprise Account Executive (US)          NaN
# 1  CS2 Cognition AI - Enterprise Account Executiv...          Hot
# 2             Enterprise Account Executive (Central)          Hot
# 3                Enterprise Account Executive - East          Hot
# 4                                     RVP Sales East          Hot
#
#        Candidate Client Contact         Job Type Interview Type  \
# 0    Erik Abbott            NaN       Contingent  1st Interview
# 1     Alek Demko    David Morse  Committed Spend  1st Interview
# 2    Colin Roper     Bryan Dell       Contingent  1st Interview
# 3    Ted O'Neill       Hao Guan       Contingent  1st Interview
# 4  TYLER FERRIER            NaN       Contingent  1st Interview
#
#   CRM Interview Type                     Source  \
# 0      1st Interview     Email & Text follow up
# 1      1st Interview           LinkedIn Message
# 2      1st Interview  LinkedIn Recruiter Inmail
# 3      1st Interview                   Bullhorn
# 4      1st Interview  LinkedIn Recruiter Inmail
#
#                        Job Owner  Job ID  Interview ID
# 0              Annalisa Girgenti     484         18866
# 1  PP Committed Spend Store - UK     710         18868
# 2                 Harry Thornton     741         18869
# 3               Samson Abodunrin     594         18872
# 4                     James Cato     725         18927

# %% [markdown]
# ### 2nd interviews

# %%
# 2nd interviews dataset
second_interviews = pd.read_csv('2nd Interviews (Last 30 Days).csv')

# First 5 rows
display(second_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date             Owner Group        Company  \
# 0      02/11/2025     02/11/2025  Samson Abodunrin  EMEA        Oscilar
# 1      02/11/2025     02/11/2025  Samson Abodunrin  EMEA        Oscilar
# 2      02/11/2025     02/11/2025  Samson Abodunrin  EMEA        Oscilar
# 3      02/11/2025     02/11/2025  Samson Abodunrin  EMEA  Safe Security
# 4      02/11/2025     02/11/2025       James Whipp  EMEA      PointFive
#
#                            Job Title Job Priority           Candidate  \
# 0  Director of Enterprise Sales (US)          Hot     Matthew Duignan
# 1                  BDR Manager - NYC          Hot  MINAS  GREGORIADES
# 2                  BDR Manager - NYC          Hot       Anthony Smyth
# 3                   Enterprise AE UK          Hot        Connor Newby
# 4  Channel & Alliances Director - UK          Hot         ABRAR AHMED
#
#     Client Contact    Job Type     Interview Type CRM Interview Type  \
# 0   Neha  Narkhede  Contingent  Further Interview      2nd Interview
# 1   Neha  Narkhede  Contingent  Further Interview      2nd Interview
# 2   Neha  Narkhede  Contingent  Further Interview      2nd Interview
# 3  Daniel  Cuffley  Contingent  Further Interview      2nd Interview
# 4              NaN  Contingent  Further Interview      2nd Interview
#
#                       Source         Job Owner  Job ID  Interview ID
# 0  LinkedIn Recruiter Inmail    Harry Thornton     556         18870
# 1  LinkedIn Recruiter Inmail  Samson Abodunrin     596         18874
# 2     Email & Text follow up  Samson Abodunrin     596         18873
# 3                   Bullhorn  Samson Abodunrin     665         18876
# 4                   Bullhorn       James Whipp     661         18875

# %% [markdown]
# ### 3rd interviews

# %%
# Interviews dataset
third_interviews = pd.read_csv('3rd Interviews (Last 30 Days).csv')

# First 5 rows
display(third_interviews.head())
# Out:
#   ﻿"Created Date" Interview Date             Owner Group        Company  \
# 0      02/11/2025     02/11/2025  Samson Abodunrin  EMEA        Oscilar
# 1      02/11/2025     02/11/2025  Samson Abodunrin  EMEA  Safe Security
# 2      02/11/2025     02/11/2025       James Whipp  EMEA      PointFive
# 3      02/11/2025     02/11/2025       James Whipp  EMEA       Capsa AI
# 4      02/11/2025     02/11/2025       James Whipp  EMEA   Cognition AI
#
#                                            Job Title Job Priority  \
# 0                  Director of Enterprise Sales (US)          Hot
# 1                                   Enterprise AE UK          Hot
# 2                                            VP EMEA          Hot
# 3                                      Head of Sales          Hot
# 4  Forward Deployed Engineer / Sales Engineer (Mi...         Warm
#
#          Candidate   Client Contact         Job Type     Interview Type  \
# 0  Matthew Duignan   Neha  Narkhede       Contingent  Further Interview
# 1     Connor Newby  Daniel  Cuffley       Contingent  Further Interview
# 2     Lewis Pinner              NaN       Contingent  Further Interview
# 3   Tom Richardson              NaN       Contingent  Further Interview
# 4      Louis Franc              NaN  Committed Spend  Further Interview
#
#   CRM Interview Type                     Source         Job Owner  Job ID  \
# 0      3rd Interview  LinkedIn Recruiter Inmail    Harry Thornton     556
# 1      3rd Interview                   Bullhorn  Samson Abodunrin     665
# 2      3rd Interview           LinkedIn Message       James Whipp     677
# 3      3rd Interview           LinkedIn Message       James Whipp     676
# 4      3rd Interview  LinkedIn Recruiter Inmail       James Whipp     714
#
#    Interview ID
# 0         18871
# 1         18877
# 2         18879
# 3         18881
# 4         18884

# %% [markdown]
# ### 4th interviews

# %%
# Interviews dataset
fourth_interviews = pd.read_csv('4th Interviews (Last 30 Days).csv')

# First 5 rows
display(fourth_interviews.tail())
# Out:
#    ﻿"Created Date" Interview Date              Owner Group       Company  \
# 45      28/11/2025     28/11/2025       Brad Houston  EMEA     Adaptive6
# 46      28/11/2025     02/12/2025        James Whipp  EMEA  Cognition AI
# 47      28/11/2025     03/12/2025        James Whipp  EMEA  Cognition AI
# 48      01/12/2025     01/12/2025  Jordan Goodenough  EMEA   Materialize
# 49      01/12/2025     01/12/2025        Lilly Tyler  EMEA     CyCognito
#
#                                             Job Title Job Priority  \
# 45                                        SE Director          Hot
# 46    Forward Deployed Engineer / Sales Engineer (UK)          Hot
# 47    Forward Deployed Engineer / Sales Engineer (UK)          Hot
# 48  CS3 Materialize - Enterprise Account Executive x3          Hot
# 49                             Enterprise AE New York          Hot
#
#              Candidate Client Contact         Job Type     Interview Type  \
# 45         Itai Heller  Shahar Geffen       Contingent  Further Interview
# 46       Michel Kiffel            NaN  Committed Spend  Further Interview
# 47        Ciaran Deasy    David Morse  Committed Spend  Further Interview
# 48         Todd Hixson   Nate Stewart  Committed Spend  Further Interview
# 49  Katie Kupferschmid            NaN       Contingent  Further Interview
#
#    CRM Interview Type                     Source  \
# 45      4th Interview  LinkedIn Recruiter Inmail
# 46      4th Interview  LinkedIn Recruiter Inmail
# 47      4th Interview  LinkedIn Recruiter Inmail
# 48      4th Interview                   Bullhorn
# 49      4th Interview                   Bullhorn
#
#                         Job Owner  Job ID  Interview ID
# 45                   Brad Houston     777         19813
# 46                 Harry Thornton     702         19819
# 47                 Harry Thornton     702         19820
# 48  PP Committed Spend Store - UK     751         19862
# 49                  Gabriel Inema     749         19864

# %% [markdown]
# ### Rejected Candidates

# %%
# Rejects dataset
rejects = pd.read_csv('Rejected Candidates (Last 30 Days).csv')

rejects.rename(columns={'﻿"Job ID"' : 'Job ID'}, inplace=True)

rejects = rejects[['Job ID', 'Job Title', 'Owner', 'Company', 'Candidate']]

# First 5 rows
display(rejects.head())

# Last 5 rows
display(rejects.tail())
# Out:
#    Job ID                               Job Title           Owner   Company  \
# 0     196  Enterprise Account Executive (Fintech)      Joe Marron  Blockaid
# 1     196  Enterprise Account Executive (Fintech)  Harry Thornton  Blockaid
# 2     196  Enterprise Account Executive (Fintech)     Max Hogarth  Blockaid
# 3     196  Enterprise Account Executive (Fintech)     Ben Clifton  Blockaid
# 4     196  Enterprise Account Executive (Fintech)     Max Hogarth  Blockaid
#
#        Candidate
# 0  Wesley Wooten
# 1     STONE GODI
# 2  DEREK ORGERON
# 3  Carlos Torres
# 4      Nik Lulla
#      Job ID                             Job Title              Owner  \
# 408     812             People Operations Manager  Annalisa Girgenti
# 409     812             People Operations Manager     Harry Thornton
# 410     814  Enterprise Account Executive Nordics        Lilly Tyler
# 411     815       Enterprise Account Executive UK  Jordan Goodenough
# 412     815       Enterprise Account Executive UK        Ben Clifton
#
#         Company          Candidate
# 408     Oscilar        MIKAYLA KIM
# 409     Oscilar     Heather Guerra
# 410      Laurel         Mads Berli
# 411  Conduct AI  David Perikhanyan
# 412  Conduct AI      Jamie Summers

# %% [markdown]
# ### Offers

# %%
# Offers dataset
offers = pd.read_csv('Offers (Last 30 Days).csv')

# First 5 rows
display(offers.head())

# Last 5 rows
display(offers.tail())
# Out:
#   ﻿"Created Date"              Owner Group    Company  \
# 0      02/11/2025  Jordan Goodenough  EMEA   Blockaid
# 1      03/11/2025         James Cato    US       Loop
# 2      03/11/2025       Brad Houston  EMEA   Blockaid
# 3      05/11/2025         Joe Marron  EMEA  Axion Ray
# 4      05/11/2025       Nick Chaplin  EMEA      Dash0
#
#                                            Job Title Job Priority  \
# 0  CS2 - Blockaid - Enterprise Account Executive ...          NaN
# 1  Delivery Transformation Lead (strat implementa...          Hot
# 2       CS2 - Blockaid - Threat Intelligence Analyst          Hot
# 3                Enterprise Account Executive (West)          Hot
# 4                                        SDR NYC x 3          Hot
#
#         Candidate                     Source       Job Owner  Job ID  \
# 0    Molly Holmes                   Referral    Brad Houston     501
# 1    Tarang Patel  LinkedIn Recruiter Inmail      James Cato     711
# 2  Nick Steegmans  LinkedIn Recruiter Inmail    Brad Houston     728
# 3   Brendan Hanke  LinkedIn Recruiter Inmail  Harry Thornton     742
# 4   Andrew Zeiser   Cold Call via Signalhire      Joe Marron     619
#
#     Offer Outcome
# 0  Offer Extended
# 1  Offer Extended
# 2  Offer Extended
# 3  Offer Extended
# 4  Offer Extended
#    ﻿"Created Date"             Owner Group           Company  \
# 28      26/11/2025  Weronika Nazarko  EMEA  Redwood Software
# 29      28/11/2025       Ben Clifton  EMEA         Axion Ray
# 30      28/11/2025        Joe Marron  EMEA      LaunchDarkly
# 31      28/11/2025      Brad Houston  EMEA          Blockaid
# 32      30/11/2025      Nick Chaplin  EMEA   Energy Robotics
#
#                                  Job Title Job Priority         Candidate  \
# 28                                   SE UK          Hot  Andrew Rushworth
# 29     Enterprise Account Executive (East)          Hot         Cam Joyce
# 30  Enterprise Account Executive (Germany)          Hot      Moritz Gross
# 31                     RevOps Manager (NY)         Warm   Kevin Venturino
# 32                             SDR Houston          Hot        Max Wilson
#
#                        Source          Job Owner  Job ID   Offer Outcome
# 28  LinkedIn Recruiter Inmail         James Cato     673  Offer Extended
# 29     Email & Text follow up     Harry Thornton     740  Offer Extended
# 30  LinkedIn Recruiter Inmail     Harry Thornton     746  Offer Extended
# 31   Cold Call via Signalhire       Brad Houston     683  Offer Extended
# 32                Sales Robot  Annalisa Girgenti     780  Offer Extended

# %% [markdown]
# ## Re-structure the data, changing their fields

# %%
# Rename the Kpi Date columns to CV Sent Date, change that to datetime type
cv_sents.rename(columns={'Created Date' : 'CV Sent Date', '﻿"Job ID"' : 'Job ID'}, inplace=True)

# Change the CV Sent Date to datetime type
cv_sents['CV Sent Date'] = pd.to_datetime(cv_sents['CV Sent Date'], format='%d/%m/%Y')
cv_sents = cv_sents[['Job ID', 'CV Sent Date', 'Owner', 'Company', 'Job Title', 'Candidate']]

# Display the new dataset
cv_sents.head()
# Out:
#    Job ID CV Sent Date         Owner   Company  \
# 0     196   2025-11-04   Sam Rudston  Blockaid
# 1     196   2025-11-04   Ben Clifton  Blockaid
# 2     196   2025-11-10   Ben Clifton  Blockaid
# 3     196   2025-11-19  Brad Houston  Blockaid
# 4     196   2025-11-26   Ben Clifton  Blockaid
#
#                                 Job Title          Candidate
# 0  Enterprise Account Executive (Fintech)  Darrell Van Dyken
# 1  Enterprise Account Executive (Fintech)    Madyson Almeida
# 2  Enterprise Account Executive (Fintech)      Dennis Coombs
# 3  Enterprise Account Executive (Fintech)  Brendan McMenimen
# 4  Enterprise Account Executive (Fintech)         Mike Gomez

# %%
# Rename the Kpi Date columns to Interview Date, change that to datetime type
first_interviews.rename(columns={'Interview Date' : '1st_Interview Date'}, inplace=True)
second_interviews.rename(columns={'Interview Date' : '2nd_Interview Date'}, inplace=True)
third_interviews.rename(columns={'Interview Date' : '3rd_Interview Date'}, inplace=True)
fourth_interviews.rename(columns={'Interview Date' : '4th_Interview Date'}, inplace=True)

# Change the Create Date to datetime type
first_interviews['1st_Interview Date'] = pd.to_datetime(first_interviews['1st_Interview Date'], format='%d/%m/%Y')
first_interviews = first_interviews[['Job ID', 'Job Title', '1st_Interview Date', 'Owner', 'Company', 'Candidate']]

second_interviews['2nd_Interview Date'] = pd.to_datetime(second_interviews['2nd_Interview Date'], format='%d/%m/%Y')
second_interviews = second_interviews[['Job ID', 'Job Title', '2nd_Interview Date', 'Owner', 'Company', 'Candidate']]

third_interviews['3rd_Interview Date'] = pd.to_datetime(third_interviews['3rd_Interview Date'], format='%d/%m/%Y')
third_interviews = third_interviews[['Job ID', 'Job Title', '3rd_Interview Date', 'Owner', 'Company', 'Candidate']]

fourth_interviews['4th_Interview Date'] = pd.to_datetime(fourth_interviews['4th_Interview Date'], format='%d/%m/%Y')
fourth_interviews = fourth_interviews[['Job ID', 'Job Title', '4th_Interview Date', 'Owner', 'Company', 'Candidate']]

# %%
# Rename the Kpi Date columns to Offer Date, change that to datetime type
offers.rename(columns={'﻿"Created Date"' : 'Offer Date'}, inplace=True)

# Change the Create Date to datetime type
offers['Placement Date'] = pd.to_datetime(offers['Offer Date'], format='%d/%m/%Y')

# Change the columns for offers
offers = offers[['Job ID', 'Job Title', 'Owner', 'Company', 'Candidate']]

# Display the new dataset
offers.head()
# Out:
#    Job ID                                          Job Title  \
# 0     501  CS2 - Blockaid - Enterprise Account Executive ...
# 1     711  Delivery Transformation Lead (strat implementa...
# 2     728       CS2 - Blockaid - Threat Intelligence Analyst
# 3     742                Enterprise Account Executive (West)
# 4     619                                        SDR NYC x 3
#
#                Owner    Company       Candidate
# 0  Jordan Goodenough   Blockaid    Molly Holmes
# 1         James Cato       Loop    Tarang Patel
# 2       Brad Houston   Blockaid  Nick Steegmans
# 3         Joe Marron  Axion Ray   Brendan Hanke
# 4       Nick Chaplin      Dash0   Andrew Zeiser

# %% [markdown]
# ## Create a few helper columns to get the status of CVs Sent to Clients

# %%
# Apply helper columns to get the status of CVs
first_interviews['Interview_1st'] = True
second_interviews['Interview_2nd'] = True
third_interviews['Interview_3rd'] = True
fourth_interviews['Interview_4th'] = True
offers['Offer'] = True
rejects['Rejected'] = True

# %%
first_interviews.head()
# Out:
#    Job ID                                          Job Title  \
# 0     484                  Enterprise Account Executive (US)
# 1     710  CS2 Cognition AI - Enterprise Account Executiv...
# 2     741             Enterprise Account Executive (Central)
# 3     594                Enterprise Account Executive - East
# 4     725                                     RVP Sales East
#
#   1st_Interview Date              Owner       Company      Candidate  \
# 0         2025-11-02        Ben Clifton  Cognition AI    Erik Abbott
# 1         2025-11-11  Jordan Goodenough  Cognition AI     Alek Demko
# 2         2025-11-04         Joe Marron     Axion Ray    Colin Roper
# 3         2025-11-02   Samson Abodunrin    Antithesis    Ted O'Neill
# 4         2025-11-03         James Cato           Rox  TYLER FERRIER
#
#    Interview_1st
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True

# %% [markdown]
# ### Merge the CV records with the interviews

# %%
# Merge the CV record with the 1st interview record
merged_cv_sent_status = cv_sents.merge(
    first_interviews,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the 2nd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    second_interviews,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the 3rd interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    third_interviews,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the 4th interview record
merged_cv_sent_status = merged_cv_sent_status.merge(
    fourth_interviews,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the offers record
merged_cv_sent_status = merged_cv_sent_status.merge(
    offers,
    on=['Company','Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Merge the CV record with the rejected record
merged_cv_sent_status = merged_cv_sent_status.merge(
    rejects,
    on=['Company', 'Job ID', 'Owner', 'Candidate', 'Job Title'],
    how='outer'
)

# Print the final list
display(merged_cv_sent_status)
# Out:
#      Job ID CV Sent Date         Owner      Company  \
# 0       767          NaT   Max Hogarth    Adaptive6
# 1       767          NaT   Max Hogarth    Adaptive6
# 2       767          NaT   Max Hogarth    Adaptive6
# 3       768   2025-11-05    Ada Sitnik    Adaptive6
# 4       768          NaT    Ada Sitnik    Adaptive6
# ..      ...          ...           ...          ...
# 724     765   2025-11-06   Sam Rudston  groundcover
# 725     765          NaT   Sam Rudston  groundcover
# 726     765   2025-11-20   Sam Rudston  groundcover
# 727     810   2025-11-13  Monie Rogers  groundcover
# 728     810   2025-11-21  Nick Chaplin  groundcover
#
#                                              Job Title           Candidate  \
# 0                    Enterprise Account Executive (US)           Dan Greer
# 1                    Enterprise Account Executive (US)         Joe Troiani
# 2                    Enterprise Account Executive (US)       Justin Briody
# 3                           Senior Sales Engineer (US)      Anthony Joanes
# 4                           Senior Sales Engineer (US)  Michael Daganhardt
# ..                                                 ...                 ...
# 724                                                SDR         Ryan Wandey
# 725                                                SDR         Sam Lefante
# 726                                                SDR         Tyler Drago
# 727  Mid-Market AE (Observability in NYC, Boston, D...  Nicholas Daileanes
# 728  Mid-Market AE (Observability in NYC, Boston, D...     Jeffrey Pereira
#
#     1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0           2025-11-12          True                NaT           NaN
# 1                  NaT           NaN                NaT           NaN
# 2                  NaT           NaN                NaT           NaN
# 3                  NaT           NaN                NaT           NaN
# 4                  NaT           NaN                NaT           NaN
# ..                 ...           ...                ...           ...
# 724         2025-11-11          True                NaT           NaN
# 725                NaT           NaN                NaT           NaN
# 726         2025-11-25          True         2025-11-28          True
# 727                NaT           NaN                NaT           NaN
# 728         2025-11-27          True                NaT           NaN
#
#     3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                  NaT           NaN                NaT           NaN   NaN
# 1                  NaT           NaN                NaT           NaN   NaN
# 2                  NaT           NaN                NaT           NaN   NaN
# 3                  NaT           NaN                NaT           NaN   NaN
# 4                  NaT           NaN                NaT           NaN   NaN
# ..                 ...           ...                ...           ...   ...
# 724                NaT           NaN                NaT           NaN   NaN
# 725                NaT           NaN         2025-11-10          True  True
# 726         2025-12-01          True                NaT           NaN   NaN
# 727                NaT           NaN                NaT           NaN   NaN
# 728                NaT           NaN                NaT           NaN   NaN
#
#     Rejected
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ..       ...
# 724     True
# 725      NaN
# 726      NaN
# 727     True
# 728      NaN
#
# [729 rows x 16 columns]

# %% [markdown]
# ### Change the status of the candidates

# %%
# Create the conditions
conditions = [
    merged_cv_sent_status['Rejected'].notna()
    merged_cv_sent_status['Interview_4th'].notna() & merged_cv_sent_status ['Rejected'].isna() & merged_cv_sent_status ['Offer'].isna(),
    merged_cv_sent_status['Interview_3rd'].notna() & merged_cv_sent_status ['Rejected'].isna() & merged_cv_sent_status ['Interview_4th'].isna(),
    merged_cv_sent_status['Interview_2nd'].notna() & merged_cv_sent_status ['Rejected'].isna() & merged_cv_sent_status ['Interview_3rd'].isna(),
    merged_cv_sent_status['Interview_1st'].notna() & merged_cv_sent_status ['Rejected'].isna() & merged_cv_sent_status ['Interview_2nd'].isna(),
    merged_cv_sent_status['Rejected'].isna() & merged_cv_sent_status['Interview_1st'].isna() & merged_cv_sent_status ['Offer'].isna()
]

# Create the choices (Interview = Converted, "Rejected = "Non-converted")
choices = [
    "Rejected",
    "4th Interview",
    "3rd Interview",
    "2nd Interview",
    "1st Interview",
    "CV Sent"
]

merged_cv_sent_status["Status"] = np.select(conditions, choices, default="N/A")

display(merged_cv_sent_status)
# Out:
#      Job ID CV Sent Date         Owner      Company  \
# 0       767          NaT   Max Hogarth    Adaptive6
# 1       767          NaT   Max Hogarth    Adaptive6
# 2       767          NaT   Max Hogarth    Adaptive6
# 3       768   2025-11-05    Ada Sitnik    Adaptive6
# 4       768          NaT    Ada Sitnik    Adaptive6
# ..      ...          ...           ...          ...
# 724     765   2025-11-06   Sam Rudston  groundcover
# 725     765          NaT   Sam Rudston  groundcover
# 726     765   2025-11-20   Sam Rudston  groundcover
# 727     810   2025-11-13  Monie Rogers  groundcover
# 728     810   2025-11-21  Nick Chaplin  groundcover
#
#                                              Job Title           Candidate  \
# 0                    Enterprise Account Executive (US)           Dan Greer
# 1                    Enterprise Account Executive (US)         Joe Troiani
# 2                    Enterprise Account Executive (US)       Justin Briody
# 3                           Senior Sales Engineer (US)      Anthony Joanes
# 4                           Senior Sales Engineer (US)  Michael Daganhardt
# ..                                                 ...                 ...
# 724                                                SDR         Ryan Wandey
# 725                                                SDR         Sam Lefante
# 726                                                SDR         Tyler Drago
# 727  Mid-Market AE (Observability in NYC, Boston, D...  Nicholas Daileanes
# 728  Mid-Market AE (Observability in NYC, Boston, D...     Jeffrey Pereira
#
#     1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 0           2025-11-12          True                NaT           NaN
# 1                  NaT           NaN                NaT           NaN
# 2                  NaT           NaN                NaT           NaN
# 3                  NaT           NaN                NaT           NaN
# 4                  NaT           NaN                NaT           NaN
# ..                 ...           ...                ...           ...
# 724         2025-11-11          True                NaT           NaN
# 725                NaT           NaN                NaT           NaN
# 726         2025-11-25          True         2025-11-28          True
# 727                NaT           NaN                NaT           NaN
# 728         2025-11-27          True                NaT           NaN
#
#     3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 0                  NaT           NaN                NaT           NaN   NaN
# 1                  NaT           NaN                NaT           NaN   NaN
# 2                  NaT           NaN                NaT           NaN   NaN
# 3                  NaT           NaN                NaT           NaN   NaN
# 4                  NaT           NaN                NaT           NaN   NaN
# ..                 ...           ...                ...           ...   ...
# 724                NaT           NaN                NaT           NaN   NaN
# 725                NaT           NaN         2025-11-10          True  True
# 726         2025-12-01          True                NaT           NaN   NaN
# 727                NaT           NaN                NaT           NaN   NaN
# 728                NaT           NaN                NaT           NaN   NaN
#
#     Rejected         Status
# 0       True       Rejected
# 1       True       Rejected
# 2       True       Rejected
# 3       True       Rejected
# 4       True       Rejected
# ..       ...            ...
# 724     True       Rejected
# 725      NaN            N/A
# 726      NaN  3rd Interview
# 727     True       Rejected
# 728      NaN  1st Interview
#
# [729 rows x 17 columns]

# %%
display(merged_cv_sent_status[merged_cv_sent_status['Owner'] == 'James Whipp'])
# Out:
#      Job ID CV Sent Date        Owner       Company  \
# 170     676          NaT  James Whipp      Capsa AI
# 171     676          NaT  James Whipp      Capsa AI
# 267     702          NaT  James Whipp  Cognition AI
# 268     702   2025-11-04  James Whipp  Cognition AI
# 269     702          NaT  James Whipp  Cognition AI
# 270     702          NaT  James Whipp  Cognition AI
# 271     702          NaT  James Whipp  Cognition AI
# 272     702          NaT  James Whipp  Cognition AI
# 273     702   2025-11-30  James Whipp  Cognition AI
# 285     714   2025-11-22  James Whipp  Cognition AI
# 286     714   2025-11-22  James Whipp  Cognition AI
# 287     714          NaT  James Whipp  Cognition AI
# 288     714   2025-11-30  James Whipp  Cognition AI
# 289     714          NaT  James Whipp  Cognition AI
# 290     714   2025-11-22  James Whipp  Cognition AI
# 291     714          NaT  James Whipp  Cognition AI
# 420     760          NaT  James Whipp        Impala
# 455     686          NaT  James Whipp     Loft Labs
# 456     686   2025-11-04  James Whipp     Loft Labs
# 457     686          NaT  James Whipp     Loft Labs
# 458     686   2025-11-04  James Whipp     Loft Labs
# 543     644          NaT  James Whipp       Orca Ai
# 582     661          NaT  James Whipp     PointFive
# 584     677   2025-11-22  James Whipp     PointFive
# 585     677   2025-11-22  James Whipp     PointFive
# 586     677          NaT  James Whipp     PointFive
# 587     677          NaT  James Whipp     PointFive
# 588     677   2025-11-22  James Whipp     PointFive
# 589     677   2025-11-30  James Whipp     PointFive
# 590     677          NaT  James Whipp     PointFive
#
#                                              Job Title            Candidate  \
# 170                                      Head of Sales      Richard Sissons
# 171                                      Head of Sales       Tom Richardson
# 267    Forward Deployed Engineer / Sales Engineer (UK)  Andrej Chomutovskij
# 268    Forward Deployed Engineer / Sales Engineer (UK)          Arya Tandon
# 269    Forward Deployed Engineer / Sales Engineer (UK)         Boaz Francis
# 270    Forward Deployed Engineer / Sales Engineer (UK)         Ciaran Deasy
# 271    Forward Deployed Engineer / Sales Engineer (UK)         Matija Bagi?
# 272    Forward Deployed Engineer / Sales Engineer (UK)        Michel Kiffel
# 273    Forward Deployed Engineer / Sales Engineer (UK)       Simone Malekar
# 285  Forward Deployed Engineer / Sales Engineer (Mi...        Aamer Mushtaq
# 286  Forward Deployed Engineer / Sales Engineer (Mi...  Andrej Chomutovskij
# 287  Forward Deployed Engineer / Sales Engineer (Mi...            April Guo
# 288  Forward Deployed Engineer / Sales Engineer (Mi...        JOSHUA TANNER
# 289  Forward Deployed Engineer / Sales Engineer (Mi...          Louis Franc
# 290  Forward Deployed Engineer / Sales Engineer (Mi...      Oliver Waterman
# 291  Forward Deployed Engineer / Sales Engineer (Mi...     Thomas Alexander
# 420                                 Head of Sales (NA)       Reed Cotterill
# 455                                         VP CS & SE        Chris Johnson
# 456                                         VP CS & SE           Dan Henley
# 457                                         VP CS & SE              Jim Ray
# 458                                         VP CS & SE        Vinay Upadhya
# 543                                 VP of Global Sales     Fabrizio Ferraro
# 582                  Channel & Alliances Director - UK          ABRAR AHMED
# 584                                            VP EMEA           Jeff Ganon
# 585                                            VP EMEA       Jeremy Perlman
# 586                                            VP EMEA           Lee Gordon
# 587                                            VP EMEA         Lewis Pinner
# 588                                            VP EMEA   Patrick Wittenberg
# 589                                            VP EMEA          Peter Reeve
# 590                                            VP EMEA        Suki Randhawa
#
#     1st_Interview Date Interview_1st 2nd_Interview Date Interview_2nd  \
# 170                NaT           NaN                NaT           NaN
# 171                NaT           NaN         2025-11-02          True
# 267         2025-11-30          True                NaT           NaN
# 268         2025-11-04          True                NaT           NaN
# 269                NaT           NaN         2025-11-02          True
# 270                NaT           NaN         2025-11-02          True
# 271                NaT           NaN                NaT           NaN
# 272                NaT           NaN         2025-11-23          True
# 273         2025-11-30          True                NaT           NaN
# 285                NaT           NaN                NaT           NaN
# 286                NaT           NaN                NaT           NaN
# 287                NaT           NaN                NaT           NaN
# 288         2025-11-30          True                NaT           NaN
# 289                NaT           NaN                NaT           NaN
# 290         2025-11-30          True                NaT           NaN
# 291                NaT           NaN         2025-11-02          True
# 420                NaT           NaN                NaT           NaN
# 455                NaT           NaN                NaT           NaN
# 456         2025-11-04          True                NaT           NaN
# 457                NaT           NaN                NaT           NaN
# 458         2025-11-04          True                NaT           NaN
# 543                NaT           NaN                NaT           NaN
# 582                NaT           NaN         2025-11-02          True
# 584         2025-11-22          True         2025-11-27          True
# 585         2025-11-22          True         2025-12-02          True
# 586                NaT           NaN                NaT           NaN
# 587                NaT           NaN         2025-11-02          True
# 588         2025-11-22          True         2025-11-23          True
# 589         2025-11-30          True                NaT           NaN
# 590                NaT           NaN                NaT           NaN
#
#     3rd_Interview Date Interview_3rd 4th_Interview Date Interview_4th Offer  \
# 170                NaT           NaN                NaT           NaN   NaN
# 171         2025-11-02          True                NaT           NaN   NaN
# 267                NaT           NaN                NaT           NaN   NaN
# 268                NaT           NaN                NaT           NaN   NaN
# 269                NaT           NaN                NaT           NaN   NaN
# 270         2025-11-23          True         2025-12-03          True   NaN
# 271                NaT           NaN                NaT           NaN   NaN
# 272         2025-11-28          True         2025-12-02          True   NaN
# 273                NaT           NaN                NaT           NaN   NaN
# 285                NaT           NaN                NaT           NaN   NaN
# 286                NaT           NaN                NaT           NaN   NaN
# 287                NaT           NaN                NaT           NaN   NaN
# 288                NaT           NaN                NaT           NaN   NaN
# 289         2025-11-02          True         2025-11-02          True   NaN
# 290                NaT           NaN                NaT           NaN   NaN
# 291                NaT           NaN                NaT           NaN   NaN
# 420                NaT           NaN                NaT           NaN   NaN
# 455                NaT           NaN                NaT           NaN   NaN
# 456                NaT           NaN                NaT           NaN   NaN
# 457                NaT           NaN                NaT           NaN   NaN
# 458                NaT           NaN                NaT           NaN   NaN
# 543                NaT           NaN                NaT           NaN  True
# 582                NaT           NaN                NaT           NaN   NaN
# 584                NaT           NaN                NaT           NaN   NaN
# 585                NaT           NaN                NaT           NaN   NaN
# 586                NaT           NaN                NaT           NaN   NaN
# 587         2025-11-02          True                NaT           NaN   NaN
# 588         2025-12-01          True                NaT           NaN   NaN
# 589                NaT           NaN                NaT           NaN   NaN
# 590                NaT           NaN                NaT           NaN   NaN
#
#     Rejected         Status
# 170     True       Rejected
# 171     True       Rejected
# 267      NaN  1st Interview
# 268     True       Rejected
# 269     True       Rejected
# 270      NaN        CV Sent
# 271     True       Rejected
# 272      NaN        CV Sent
# 273      NaN  1st Interview
# 285      NaN        CV Sent
# 286      NaN        CV Sent
# 287     True       Rejected
# 288      NaN  1st Interview
# 289     True       Rejected
# 290      NaN  1st Interview
# 291     True       Rejected
# 420     True       Rejected
# 455     True       Rejected
# 456     True       Rejected
# 457     True       Rejected
# 458     True       Rejected
# 543      NaN            N/A
# 582     True       Rejected
# 584      NaN  2nd Interview
# 585      NaN  2nd Interview
# 586     True       Rejected
# 587     True       Rejected
# 588      NaN  3rd Interview
# 589      NaN  1st Interview
# 590     True       Rejected

# %% [markdown]
# ### Add the column of Action Date - Interview/CV Sent Date

# %%
def get_action_date(row):
    status = row['Status']
    
    # Map status to the corresponding column name
    if status == 'CV Sent':
        return row['CV Sent Date']
    elif status == '1st Interview':
        return row['1st_Interview Date']
    elif status == '2nd Interview':
        return row['2nd_Interview Date']
    elif status == '3rd Interview':
        return row['3rd_Interview Date']
    elif status == '4th Interview':
        return row['4th_Interview Date']
    else:
        return pd.NaT # Return "Not a Time" for unknown statuses

# --- Apply the Function ---
merged_cv_sent_status['Action Date'] = merged_cv_sent_status.apply(get_action_date, axis=1)

# %%
# Drop the N/A rows in the status
merged_cv_sent_status = merged_cv_sent_status[(merged_cv_sent_status.Status != 'N/A') & (merged_cv_sent_status.Status != 'Rejected')]

merged_cv_sent_status['Status'].value_counts()
# Out:
# Status
# 1st Interview    113
# CV Sent          101
# 2nd Interview     42
# 3rd Interview     19
# 4th Interview      8
# Name: count, dtype: int64

# %%
# Drop the support columns
merged_cv_sent_status = merged_cv_sent_status.drop(columns = ['Interview_1st', 'Interview_2nd', 'Interview_3rd', 'Interview_4th', 'Rejected', 'Offer', 
                                                              '1st_Interview Date', '2nd_Interview Date', '3rd_Interview Date', '4th_Interview Date'])

# %%
display(merged_cv_sent_status)
# Out:
#      Job ID CV Sent Date             Owner      Company  \
# 7       768   2025-11-27  Weronika Nazarko    Adaptive6
# 9       768   2025-11-25  Weronika Nazarko    Adaptive6
# 11      777   2025-11-13      Brad Houston    Adaptive6
# 13      777   2025-11-27      Brad Houston    Adaptive6
# 14      777   2025-11-05      Brad Houston    Adaptive6
# ..      ...          ...               ...          ...
# 711     610   2025-11-11      Nick Chaplin       WorkOS
# 719     765   2025-11-25       Sam Rudston  groundcover
# 722     765   2025-11-25       Sam Rudston  groundcover
# 726     765   2025-11-20       Sam Rudston  groundcover
# 728     810   2025-11-21      Nick Chaplin  groundcover
#
#                                              Job Title        Candidate  \
# 7                           Senior Sales Engineer (US)     Artur Sirota
# 9                           Senior Sales Engineer (US)   Matthew Hughes
# 11                                         SE Director      Brendan Cox
# 13                                         SE Director    Hermann Hesse
# 14                                         SE Director      Itai Heller
# ..                                                 ...              ...
# 711           Enterprise Account Executive San Fran x2    Matthew Lange
# 719                                                SDR   Cesar Castillo
# 722                                                SDR    JJ Valderrama
# 726                                                SDR      Tyler Drago
# 728  Mid-Market AE (Observability in NYC, Boston, D...  Jeffrey Pereira
#
#             Status Action Date
# 7          CV Sent  2025-11-27
# 9          CV Sent  2025-11-25
# 11   1st Interview  2025-11-17
# 13         CV Sent  2025-11-27
# 14   4th Interview  2025-11-28
# ..             ...         ...
# 711        CV Sent  2025-11-11
# 719        CV Sent  2025-11-25
# 722        CV Sent  2025-11-25
# 726  3rd Interview  2025-12-01
# 728  1st Interview  2025-11-27
#
# [283 rows x 8 columns]

# %%
display(merged_cv_sent_status[merged_cv_sent_status['Status'] == '4th Interview'])
# Out:
#      Job ID CV Sent Date              Owner      Company  \
# 14      777   2025-11-05       Brad Houston    Adaptive6
# 308     749   2025-11-11        Lilly Tyler    CyCognito
# 311     749   2025-11-13        Lilly Tyler    CyCognito
# 359     785          NaT       Monie Rogers        Dash0
# 470     711   2025-11-05         James Cato         Loop
# 513     751   2025-11-13  Jordan Goodenough  Materialize
# 567     731   2025-11-05   Samson Abodunrin      Oscilar
# 679     770   2025-11-11        Max Hogarth     TraceBit
#
#                                              Job Title           Candidate  \
# 14                                         SE Director         Itai Heller
# 308                             Enterprise AE New York        Brett Arpaia
# 311                             Enterprise AE New York  Katie Kupferschmid
# 359                            Commercial AE Amsterdam       Oskar Stepien
# 470  Delivery Transformation Lead (strat implementa...         Noel Thomas
# 513  CS3 Materialize - Enterprise Account Executive x3         Todd Hixson
# 567                                   Enterprise AE x5       Jason Fulwood
# 679                              Account Executive NYC        Ben Brighton
#
#             Status Action Date
# 14   4th Interview  2025-11-28
# 308  4th Interview  2025-11-28
# 311  4th Interview  2025-12-01
# 359  4th Interview  2025-11-21
# 470  4th Interview  2026-01-07
# 513  4th Interview  2025-12-01
# 567  4th Interview  2025-11-23
# 679  4th Interview  2025-12-01

# %%
display(merged_cv_sent_status[merged_cv_sent_status['Job ID'] == 707])
# Out:
#      Job ID CV Sent Date             Owner Company  \
# 343     707   2025-11-25  Weronika Nazarko   Dash0
# 345     707   2025-11-27  Weronika Nazarko   Dash0
#
#                                              Job Title         Candidate  \
# 343  Sales Engineer EMEA (UK, Nordics, Benelux, Ger...      Harry Kimpel
# 345  Sales Engineer EMEA (UK, Nordics, Benelux, Ger...  Patrick Schrimpf
#
#             Status Action Date
# 343  1st Interview  2025-12-01
# 345  1st Interview  2025-12-02

# %% [markdown]
# ## Export the in-play candidates for the recruiters

# %%
owners_list = merged_cv_sent_status['Owner'].dropna().unique()

merged_cv_sent_status['Action Date'].dt.floor('d')

# Create a folder to keep things organised
output_folder = 'Consultant_Active_Reports'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
for owner in owners_list:
    # 1. Filter for this specific owner
    owner_data = merged_cv_sent_status[merged_cv_sent_status['Owner'] == owner].copy()
    
    # 2. Sort by Job ID (Ascending)
    owner_data = owner_data.sort_values(by='Job ID', ascending=True)
    
    # 3. Select clean columns for the consultant
    export_cols = ['Job ID', 'Company', 'Job Title', 'Candidate', 'Status', 'Action Date']
    final_export = owner_data[export_cols]
    
    # 4. Define Filename (Clean the name to avoid file errors)
    clean_owner_name = str(owner).replace(" ", "_").replace("/", "-")
    filename = f"{output_folder}/Active_Candidates_{clean_owner_name}.xlsx"
    
    # 5. Export to Excel
    final_export.to_excel(filename, index=False)
    
    print(f"Exported: {filename} ({len(final_export)} candidates)")

print("\n--- ALL EXPORTS COMPLETE ---")
# Out:
# Exported: Consultant_Active_Reports/Active_Candidates_Weronika_Nazarko.xlsx (27 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Brad_Houston.xlsx (23 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Jordan_Goodenough.xlsx (20 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Max_Hogarth.xlsx (15 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ben_Clifton.xlsx (28 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Gabriel_Inema.xlsx (3 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Monie_Rogers.xlsx (20 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Samson_Abodunrin.xlsx (26 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Joe_Marron.xlsx (26 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Sam_Rudston.xlsx (12 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Ada_Sitnik.xlsx (11 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Harry_Thornton.xlsx (7 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Nick_Chaplin.xlsx (13 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Cato.xlsx (15 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_James_Whipp.xlsx (12 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Charlotte_Wells.xlsx (8 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Lilly_Tyler.xlsx (7 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Georgia_Price.xlsx (5 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Annalisa_Girgenti.xlsx (4 candidates)
# Exported: Consultant_Active_Reports/Active_Candidates_Connor_Cook.xlsx (1 candidates)
#
# --- ALL EXPORTS COMPLETE ---
